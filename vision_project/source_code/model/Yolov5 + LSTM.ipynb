# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# - Yolov5 torch_버전 불러오기

# %%
# Yolov5 requirements
# !pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt
# Out:
# /bin/pip:6: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import load_entry_point
# Requirement already satisfied: gitpython>=3.1.30 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (3.7.5)
# Requirement already satisfied: numpy>=1.23.5 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 7)) (1.24.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: pillow>=10.3.0 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 10)) (5.5.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/lib/python3/dist-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 11)) (5.3.1)
# Requirement already satisfied: requests>=2.32.0 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 13)) (1.10.1)
# Requirement already satisfied: thop>=0.1.1 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (2.4.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 16)) (0.19.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 17)) (4.66.1)
# Requirement already satisfied: ultralytics>=8.2.34 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 18)) (8.2.74)
# Requirement already satisfied: pandas>=1.1.4 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 27)) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in /home/nkw/.local/lib/python3.8/site-packages (from -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 42)) (72.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/nkw/.local/lib/python3.8/site-packages (from gitpython>=3.1.30->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nkw/.local/lib/python3.8/site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/nkw/.local/lib/python3.8/site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nkw/.local/lib/python3.8/site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/nkw/.local/lib/python3.8/site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/nkw/.local/lib/python3.8/site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nkw/.local/lib/python3.8/site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/nkw/.local/lib/python3.8/site-packages (from matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (6.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nkw/.local/lib/python3.8/site-packages (from requests>=2.32.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.32.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.32.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.32.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 12)) (2019.11.28)
# Requirement already satisfied: filelock in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (4.10.0)
# Requirement already satisfied: sympy in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (3.1.3)
# Requirement already satisfied: fsspec in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: triton==3.0.0; platform_system == "Linux" and platform_machine == "x86_64" and python_version < "3.13" in /home/nkw/.local/lib/python3.8/site-packages (from torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: py-cpuinfo in /home/nkw/.local/lib/python3.8/site-packages (from ultralytics>=8.2.34->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/nkw/.local/lib/python3.8/site-packages (from ultralytics>=8.2.34->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 18)) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /home/nkw/.local/lib/python3.8/site-packages (from pandas>=1.1.4->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/nkw/.local/lib/python3.8/site-packages (from pandas>=1.1.4->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/nkw/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/nkw/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib>=3.3->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 6)) (3.19.2)
# Requirement already satisfied: mpmath>=0.19 in /home/nkw/.local/lib/python3.8/site-packages (from sympy->torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nkw/.local/lib/python3.8/site-packages (from jinja2->torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/nkw/.local/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.8.0->-r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt (line 15)) (12.4.99)

# %%
# torch_ver Yolov5
import torch

yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s',
                            device='cuda:0' if torch.cuda.is_available() else 'cpu')  # 예측 모델
yolo_model.classes = [0]  # 예측 클래스 (0 : 사람)
# Out:
# Using cache found in /home/nkw/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-8-11 Python-3.8.10 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24257MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:01<00:00, 11.7MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# colab 환경에서는 mediapipe install
# !pip install mediapipe

# %%
import cv2
import mediapipe as mp
import numpy as np
import os
import random
import gc
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt

from IPython.display import Image, clear_output
from torch.cuda import memory_allocated, empty_cache
from torch.optim import Adam
from torch.utils.data import random_split
from torch.utils.data import Dataset, DataLoader
from glob import glob
from tqdm import tqdm
# from google.colab.patches import cv2_imshow

# %matplotlib inline

# 이미지 저장 및 출력 함수
def save_and_display_image(img, file_name='output_image.png'):
    # 이미지를 파일로 저장
    cv2.imwrite(file_name, img)
    # 저장된 이미지를 matplotlib을 통해 출력
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # OpenCV는 BGR 포맷을 사용하므로, RGB로 변환 필요
    plt.imshow(img)
    plt.axis('off')  # 축 제거
    plt.show()

# %% [markdown]
# - 데이터 전처리 및 세부 조정

# %%
BATCH_SIZE = 6
EPOCH = 700
NUM_LAYERS = 1      # LSTM model: num_layers
start_dot = 11      # mp.solutions.pose 시작 포인트 (0: 얼굴부터 발목까지, 11: 어깨부터 발목까지)
n_CONFIDENCE = 0.3    # MediaPipe Min Detectin confidence check
y_CONFIDENCE = 0.3    # Yolv5 Min Detectin confidence check

mp_pose = mp.solutions.pose
attention_dot = [n for n in range(start_dot, 29)]

# 라인 그리기
if start_dot == 11:
    """몸 부분만"""
    draw_line = [[11, 13], [13, 15], [15, 21], [15, 19], [15, 17], [17, 19], \
                [12, 14], [14, 16], [16, 22], [16, 20], [16, 18], [18, 20], \
                [23, 25], [25, 27], [24, 26], [26, 28], [11, 12], [11, 23], \
                [23, 24], [12, 24]]
    print('Pose : Only Body')

else:
    """얼굴 포함"""
    draw_line = [[11, 13], [13, 15], [15, 21], [15, 19], [15, 17], [17, 19], \
                [12, 14], [14, 16], [16, 22], [16, 20], [16, 18], [18, 20], \
                [23, 25], [25, 27], [24, 26], [26, 28], [11, 12], [11, 23], \
                [23, 24], [12, 24], [9, 10], [0, 5], [0, 2], [5, 8], [2, 7]]
    print('Pose : Face + Body')
# Out:
# Pose : Only Body

# %%
# Yolov4 바운딩 box 안에서 media pipe 데이터 전처리 함수

def get_skeleton(video_path, attention_dot, draw_line):
    frame_length = 30 # LSTM 모델에 넣을 frame 수

    xy_list_list, xy_list_list_flip = [], []
    cv2.destroyAllWindows()
    pose = mp_pose.Pose(static_image_mode = True, model_complexity = 1, \
                        enable_segmentation = False, min_detection_confidence = n_CONFIDENCE)
    cap = cv2.VideoCapture(video_path)

    if cap.isOpened():

        while True:
            ret, img = cap.read()

            if ret == True:

                """ Yolo 바운딩 박스 및 좌표 추출"""
                img = cv2.resize(img, (640, 640))
                res = yolo_model(img)
                res_refine = res.pandas().xyxy[0].values
                nms_human = len(res_refine)
                if nms_human > 0:
                    for bbox in res_refine:
                        """바운딩 박스 상하좌우 크기 조절"""
                        xx1, yy1, xx2, yy2 = int(bbox[0])-10, int(bbox[1]), int(bbox[2])+10, int(bbox[3])
                        if xx1 < 0:
                            xx1 = 0
                        elif xx2 > 639:
                            xx2 = 639
                        if yy1 < 0:
                            yy1 = 0
                        elif yy2 > 639:
                            yy2 = 639

                        start_point = (xx1, yy1)
                        end_point = (xx2, yy2)

                        """ Yolov5 바운딩 박스 좌표 안에서 mediapipe Pose 추출"""
                        if bbox[4] > y_CONFIDENCE: # bbox[4] : confidence 데이터
                            # img = cv2.rectangle(img, start_point, end_point, (0, 0, 255), 2) # 바운딩 박스 그리기 : 데이터 추출 확인용
                            c_img = img[yy1:yy2, xx1:xx2] # 바운딩 박스 좌표
                            results = pose.process(cv2.cvtColor(c_img, cv2.COLOR_BGR2RGB)) # Yolov5 바운딩 박스 좌표 안에서 'mp_pose' 좌표

                            if not results.pose_landmarks: continue
                            idx = 0
                            draw_line_dic = {}
                            xy_list, xy_list_flip = [], []
                            # 33 반복문 진행 : 33개 중 18개의 dot
                            for x_and_y in results.pose_landmarks.landmark:
                                if idx in attention_dot:
                                    xy_list.append(x_and_y.x)
                                    xy_list.append(x_and_y.y)
                                    xy_list_flip.append(1 - x_and_y.x)
                                    xy_list_flip.append(x_and_y.y)

                                    x, y = int(x_and_y.x*(xx2-xx1)), int(x_and_y.y*(yy2-yy1))
                                    draw_line_dic[idx] = [x, y]
                                idx += 1

                            if len(xy_list) != len(attention_dot) * 2:
                                print('Error : attention_dot 데이터 오류')

                            xy_list_list.append(xy_list)
                            xy_list_list_flip.append(xy_list_flip)

                            """mediapipe line 그리기 부분 : 데이터 추출(dot) 확인용"""
                            # for line in draw_line:
                            #     x1, y1 = draw_line_dic[line[0]][0], draw_line_dic[line[0]][1]
                            #     x2, y2 = draw_line_dic[line[1]][0], draw_line_dic[line[1]][1]
                            #     c_img = cv2.line(c_img, (x1, y1), (x2, y2), (0, 255, 0), 4)
                            # # cv2.imshow('Landmark Image', img)
                            # cv2_imshow(img)
                            # cv2.waitKey(1)

            elif ret == False: break


        # 부족한 프레임 수 맞추기
        if len(xy_list_list_flip) < 15:
            return False, False
        elif len(xy_list_list_flip) < frame_length:
            f_ln = frame_length - len(xy_list_list_flip)
            for _ in range(f_ln):
                xy_list_list.append(xy_list_list[-1])
                xy_list_list_flip.append(xy_list_list_flip[-1])

    cap.release()
    cv2.destroyAllWindows()


    return xy_list_list, xy_list_list_flip

# %%
# video_path = '/content/drive/MyDrive/Colab_Notebooks/LSTM/datasets' # dataset 경로
video_path = '/home/nkw/ihs/ihs2/zerobase_DL_project/datas/dataset' # dataset 경로
video_path
# Out:
# '/home/nkw/ihs/ihs2/zerobase_DL_project/datas/dataset'

# %%
# 폴더 내용물 출력
for fold in os.listdir(video_path):
    print(f"Directory: {fold}")
    for video_name in os.listdir(os.path.join(video_path, fold)):
        print(f"  File: {video_name}")
# Out:
# Directory: abnormal
#   File: 08_bag_30.mp4
#   File: 03_pocket_30.mp4
#   File: 09_bag_30.mp4
#   File: 04_pocket_30.mp4
#   File: 02_pocket_30.mp4
#   File: 01_pocket_30.mp4
#   File: 07_bag_30.mp4
#   File: 05_pocket_30.mp4
#   File: 06_pocket_30.mp4
#   File: 10_bag_30.mp4
# Directory: normal
#   File: 06_normal_30.mp4
#   File: 05_normal_30.mp4
#   File: 01_normal_30.mp4
#   File: 08_normal_30.mp4
#   File: 02_normal_30.mp4
#   File: 10_normal_30.mp4
#   File: 04_normal_30.mp4
#   File: 09_normal_30.mp4
#   File: 07_normal_30.mp4
#   File: 03_normal_30.mp4

# %%
# yolo_model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # YOLOv5s 모델 로드
# Out:
# Using cache found in /home/nkw/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-8-11 Python-3.8.10 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24257MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# 영상 데이터에서 mp pose landmark dot 데이터 추출 부분
raw_data = []

for fold in os.listdir(video_path):
    for video_name in os.listdir(os.path.join(video_path, fold)):
        video_name_parts = video_name.split('_')
        if len(video_name_parts) >= 3:  # video_name이 예상대로 3개 이상의 파트로 구성된 경우에만 처리
            try:
                if int(video_name_parts[-1].split('.')[0]) >= 30:  # video name에서 마지막 숫자 확인
                    label = 0 if video_name_parts[1] == 'normal' else 1
                    skel_data_n, skel_data_f = get_skeleton(os.path.join(video_path, fold, video_name), attention_dot, draw_line)
                    
                    # 디버깅 출력 추가
                    print(f"Processing {video_name} - Label: {label}")
                    
                    if skel_data_n:
                        seq_list_n = skel_data_n[:30]
                        seq_list_f = skel_data_f[:30]
                        raw_data.append({'key': label, 'value': seq_list_n})
                        raw_data.append({'key': label, 'value': seq_list_f})
                        print(f"Added data - Key: {label}")
            except ValueError:
                print(f"Error processing file: {video_name}")

random.shuffle(raw_data)
print(f"Final raw_data length: {len(raw_data)}")
print(f"Raw data contents: {raw_data}")
# Out:
# I0000 00:00:1723524907.414994 1328244 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1723524907.423709 1329344 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3090/PCIe/SSE2
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing 08_bag_30.mp4 - Label: 1
# Added data - Key: 1
# I0000 00:00:1723524913.162242 1328244 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1723524913.172951 1329382 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3090/PCIe/SSE2
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing 03_pocket_30.mp4 - Label: 1
# Added data - Key: 1
# I0000 00:00:1723524921.573580 1328244 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1723524921.582543 1329419 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3090/PCIe/SSE2
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing 09_bag_30.mp4 - Label: 1
# Added data - Key: 1
# I0000 00:00:1723524926.872137 1328244 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1723524926.880455 1329456 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3090/PCIe/SSE2
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing 04_pocket_30.mp4 - Label: 1
# Added data - Key: 1
# I0000 00:00:1723524935.458961 1328244 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1723524935.467413 1329494 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3090/PCIe/SSE2
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing 02_pocket_30.mp4 - Label: 1
# Added data - Key: 1
# I0000 00:00:1723524944.376758 1328244 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1723524944.385032 1329531 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3090/PCIe/SSE2
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing 01_pocket_30.mp4 - Label: 1
# Added data - Key: 1
# I0000 00:00:1723524953.670758 1328244 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1723524953.678402 1329568 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3090/PCIe/SSE2
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing 07_normal_30.mp4 - Label: 0
# Added data - Key: 0
# I0000 00:00:1723525019.637945 1328244 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1723525019.646901 1330090 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3090/PCIe/SSE2
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Processing 03_normal_30.mp4 - Label: 0
# Added data - Key: 0
# Final raw_data length: 40
# Raw data contents: [{'key': 0, 'value': [[0.4363498091697693, 0.25077927112579346, 0.8052356541156769, 0.2357235997915268, 0.34291350841522217, 0.4300210773944855, 0.8488611876964569, 0.38547614216804504, 0.2918161153793335, 0.5870980620384216, 0.9260814487934113, 0.48366251587867737, 0.23058342933654785, 0.6265225410461426, 0.9391724765300751, 0.5160379409790039, 0.2704721689224243, 0.6298372149467468, 0.9335095882415771, 0.5095565319061279, 0.3031829595565796, 0.6170740127563477, 0.9092893004417419, 0.4996867775917053, 0.49744343757629395, 0.5176143050193787, 0.6734113395214081, 0.520902156829834, 0.4550364017486572, 0.7192281484603882, 0.5828977525234222, 0.7150613069534302, 0.30911028385162354, 0.851832926273346, 0.48581188917160034, 0.8751221895217896], [0.38892537355422974, 0.6974974274635315, 0.7910419404506683, 0.7316592335700989, 0.18693959712982178, 0.8196382522583008, 0.7777382135391235, 0.9189271926879883, 0.27339327335357666, 0.7970449924468994, 0.7441090643405914, 0.8295223712921143, 0.2777774930000305, 0.8019406199455261, 0.7207617461681366, 0.8195944428443909, 0.30472517013549805, 0.7704918384552002, 0.7680137455463409, 0.7831892371177673, 0.3107123374938965, 0.771327018737793, 0.7698689103126526, 0.7896926403045654, 0.42685598134994507, 1.2124559879302979, 0.6421725749969482, 1.2346563339233398, 0.33655446767807007, 1.0337077379226685, 0.6312339305877686, 1.0629799365997314, 0.5158323049545288, 1.1443061828613281, 0.5315842032432556, 1.1144684553146362], [0.4723665714263916, 0.7656729817390442, 0.5078851580619812, 0.7892405986785889, 0.6493746638298035, 0.5737526416778564, 0.6121667921543121, 0.6610090732574463, 0.7721672654151917, 0.2712104320526123, 0.7253407835960388, 0.2655365467071533, 0.7968306839466095, 0.18325364589691162, 0.6828699111938477, 0.30400407314300537, 0.7756549119949341, 0.1651827096939087, 0.7499728500843048, 0.21036885678768158, 0.7690842300653458, 0.1968468427658081, 0.702237069606781, 0.2979375123977661, 0.6017042398452759, 1.282366156578064, 0.6331766247749329, 1.2590603828430176, 0.6313280463218689, 0.9739210605621338, 0.6950004696846008, 0.9201039671897888, 0.8709118068218231, 0.7587110996246338, 0.8285431861877441, 0.7296488285064697], [0.44056951999664307, 0.23667635023593903, 0.8063513934612274, 0.23316286504268646, 0.34275829792022705, 0.39177247881889343, 0.8403128385543823, 0.3677125871181488, 0.2626412510871887, 0.537536084651947, 0.7973781526088715, 0.48741260170936584, 0.2134772539138794, 0.5774641036987305, 0.8519614934921265, 0.5228889584541321, 0.24271762371063232, 0.5821855068206787, 0.7934988439083099, 0.5250021815299988, 0.27282315492630005, 0.568342387676239, 0.7746210545301437, 0.519488513469696, 0.4735201597213745, 0.49364763498306274, 0.6695803701877594, 0.4934692978858948, 0.4271738529205322, 0.6983110308647156, 0.5763837397098541, 0.6872551441192627, 0.35737335681915283, 0.8731477856636047, 0.4405342936515808, 0.8503791093826294], [0.31049835681915283, 0.413879930973053, 0.6568298935890198, 0.4639210104942322, 0.14739787578582764, 0.5463114976882935, 0.6292131841182709, 0.6428264379501343, 0.25411713123321533, 0.5604698657989502, 0.5417251288890839, 0.7396606206893921, 0.275274395942688, 0.5687966346740723, 0.5187004506587982, 0.7810320854187012, 0.29193663597106934, 0.5559458136558533, 0.5147160887718201, 0.7641873955726624, 0.2993907928466797, 0.5584716796875, 0.5080897212028503, 0.751406192779541, 0.2873649597167969, 0.8318638801574707, 0.5090477168560028, 0.8487918972969055, 0.19927352666854858, 1.0399422645568848, 0.5060662031173706, 1.0849517583847046, 0.24031978845596313, 1.2848247289657593, 0.39307743310928345, 1.3238886594772339], [0.5686058402061462, 0.2461491823196411, 0.8323168009519577, 0.24551747739315033, 0.4948025941848755, 0.3996897041797638, 0.832906186580658, 0.373227059841156, 0.44549238681793213, 0.5467451810836792, 0.7905729115009308, 0.4792417585849762, 0.4122220277786255, 0.5874012112617493, 0.7984687387943268, 0.5012043118476868, 0.438493 ...

# %%
print(raw_data)  # raw_data 리스트의 내용을 출력
# Out:
# [{'key': 0, 'value': [[0.4363498091697693, 0.25077927112579346, 0.8052356541156769, 0.2357235997915268, 0.34291350841522217, 0.4300210773944855, 0.8488611876964569, 0.38547614216804504, 0.2918161153793335, 0.5870980620384216, 0.9260814487934113, 0.48366251587867737, 0.23058342933654785, 0.6265225410461426, 0.9391724765300751, 0.5160379409790039, 0.2704721689224243, 0.6298372149467468, 0.9335095882415771, 0.5095565319061279, 0.3031829595565796, 0.6170740127563477, 0.9092893004417419, 0.4996867775917053, 0.49744343757629395, 0.5176143050193787, 0.6734113395214081, 0.520902156829834, 0.4550364017486572, 0.7192281484603882, 0.5828977525234222, 0.7150613069534302, 0.30911028385162354, 0.851832926273346, 0.48581188917160034, 0.8751221895217896], [0.38892537355422974, 0.6974974274635315, 0.7910419404506683, 0.7316592335700989, 0.18693959712982178, 0.8196382522583008, 0.7777382135391235, 0.9189271926879883, 0.27339327335357666, 0.7970449924468994, 0.7441090643405914, 0.8295223712921143, 0.2777774930000305, 0.8019406199455261, 0.7207617461681366, 0.8195944428443909, 0.30472517013549805, 0.7704918384552002, 0.7680137455463409, 0.7831892371177673, 0.3107123374938965, 0.771327018737793, 0.7698689103126526, 0.7896926403045654, 0.42685598134994507, 1.2124559879302979, 0.6421725749969482, 1.2346563339233398, 0.33655446767807007, 1.0337077379226685, 0.6312339305877686, 1.0629799365997314, 0.5158323049545288, 1.1443061828613281, 0.5315842032432556, 1.1144684553146362], [0.4723665714263916, 0.7656729817390442, 0.5078851580619812, 0.7892405986785889, 0.6493746638298035, 0.5737526416778564, 0.6121667921543121, 0.6610090732574463, 0.7721672654151917, 0.2712104320526123, 0.7253407835960388, 0.2655365467071533, 0.7968306839466095, 0.18325364589691162, 0.6828699111938477, 0.30400407314300537, 0.7756549119949341, 0.1651827096939087, 0.7499728500843048, 0.21036885678768158, 0.7690842300653458, 0.1968468427658081, 0.702237069606781, 0.2979375123977661, 0.6017042398452759, 1.282366156578064, 0.6331766247749329, 1.2590603828430176, 0.6313280463218689, 0.9739210605621338, 0.6950004696846008, 0.9201039671897888, 0.8709118068218231, 0.7587110996246338, 0.8285431861877441, 0.7296488285064697], [0.44056951999664307, 0.23667635023593903, 0.8063513934612274, 0.23316286504268646, 0.34275829792022705, 0.39177247881889343, 0.8403128385543823, 0.3677125871181488, 0.2626412510871887, 0.537536084651947, 0.7973781526088715, 0.48741260170936584, 0.2134772539138794, 0.5774641036987305, 0.8519614934921265, 0.5228889584541321, 0.24271762371063232, 0.5821855068206787, 0.7934988439083099, 0.5250021815299988, 0.27282315492630005, 0.568342387676239, 0.7746210545301437, 0.519488513469696, 0.4735201597213745, 0.49364763498306274, 0.6695803701877594, 0.4934692978858948, 0.4271738529205322, 0.6983110308647156, 0.5763837397098541, 0.6872551441192627, 0.35737335681915283, 0.8731477856636047, 0.4405342936515808, 0.8503791093826294], [0.31049835681915283, 0.413879930973053, 0.6568298935890198, 0.4639210104942322, 0.14739787578582764, 0.5463114976882935, 0.6292131841182709, 0.6428264379501343, 0.25411713123321533, 0.5604698657989502, 0.5417251288890839, 0.7396606206893921, 0.275274395942688, 0.5687966346740723, 0.5187004506587982, 0.7810320854187012, 0.29193663597106934, 0.5559458136558533, 0.5147160887718201, 0.7641873955726624, 0.2993907928466797, 0.5584716796875, 0.5080897212028503, 0.751406192779541, 0.2873649597167969, 0.8318638801574707, 0.5090477168560028, 0.8487918972969055, 0.19927352666854858, 1.0399422645568848, 0.5060662031173706, 1.0849517583847046, 0.24031978845596313, 1.2848247289657593, 0.39307743310928345, 1.3238886594772339], [0.5686058402061462, 0.2461491823196411, 0.8323168009519577, 0.24551747739315033, 0.4948025941848755, 0.3996897041797638, 0.832906186580658, 0.373227059841156, 0.44549238681793213, 0.5467451810836792, 0.7905729115009308, 0.4792417585849762, 0.4122220277786255, 0.5874012112617493, 0.7984687387943268, 0.5012043118476868, 0.4384932518005371, 0.58953 ...

# %%
# dataset 길이 출력

nd = 0
ad = 0
for i in range(len(raw_data)):
    if raw_data[i]['key'] == 0:
        nd += 1
    else:
        ad += 1
print('normal data:', nd, '| abnormal data:', ad)
# Out:
# normal data: 20 | abnormal data: 20

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# - 모델링

# %%
class MyDataset(Dataset):
    def __init__(self, seq_list):
        self.X = []
        self.y = []
        for dic in seq_list :
            self.y.append(dic['key'])
            self.X.append(dic['value'])

    def __getitem__(self, index):
        data = self.X[index]
        label = self.y[index]
        return torch.Tensor(np.array(data)), torch.tensor(np.array(int(label)))

    def __len__(self):
        return len(self.X)

# %%
split_ratio = [0.8, 0.1, 0.1]
train_len = int(len(raw_data) * split_ratio[0])
val_len = int(len(raw_data) * split_ratio[1])
test_len = len(raw_data) - train_len - val_len

print('{}, {}, {}'.format(train_len, val_len, test_len))
# Out:
# 32, 4, 4

# %%
train_dataset = MyDataset(raw_data)
train_data, valid_data, test_data = random_split(train_dataset, [train_len, val_len, test_len])

train_loader = DataLoader(train_data, batch_size=BATCH_SIZE)
val_loader = DataLoader(valid_data, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
# LSTM
class skeleton_LSTM(nn.Module):
    def __init__(self):
        super(skeleton_LSTM, self).__init__()
        self.lstm1 = nn.LSTM(input_size=len(attention_dot) * 2, hidden_size=128, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=128, hidden_size=256, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm3 = nn.LSTM(input_size=256, hidden_size=512, num_layers=NUM_LAYERS, batch_first=True)
        self.dropout1 = nn.Dropout(0.1)
        self.lstm4 = nn.LSTM(input_size=512, hidden_size=256, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm5 = nn.LSTM(input_size=256, hidden_size=128, num_layers=NUM_LAYERS, batch_first=True)
        self.lstm6 = nn.LSTM(input_size=128, hidden_size=64, num_layers=NUM_LAYERS, batch_first=True)
        self.dropout2 = nn.Dropout(0.1)
        self.lstm7 = nn.LSTM(input_size=64, hidden_size=32, num_layers=NUM_LAYERS, batch_first=True)
        self.fc = nn.Linear(32,2)

    def forward(self, x) :
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x, _ = self.lstm3(x)
        x = self.dropout1(x)
        x, _ = self.lstm4(x)
        x, _ = self.lstm5(x)
        x, _ = self.lstm6(x)
        x = self.dropout2(x)
        x, _ = self.lstm7(x)
        x = self.fc(x[:,-1,:]) # x[배치 크기, 시퀀스 길이, 은닉 상태 크기], [:, -1, :] -> 마지막 시간 단계만 선택

        return x

# %%
# 모델 초기화

def init_model():
    global net, loss_fn, optim
    plt.rc('font', size = 10)
    net = skeleton_LSTM().to(device)
    loss_fn = nn.CrossEntropyLoss()
    optim = Adam(net.parameters(), lr=0.0001)

# epoch 카운터 초기화
def init_epoch():
    global epoch_cnt
    epoch_cnt = 0

# 모든 Log를 초기화
def init_log():
    global log_stack, iter_log, tloss_log, tacc_log, vloss_log, vacc_log, time_log
    plt.rc('font', size = 10)
    iter_log, tloss_log, tacc_log, vloss_log, vacc_log = [], [], [], [], []
    time_log, log_stack = [], []

# %%
def record_train_log(_tloss, _tacc, _time):
    # Train Log 기록
    time_log.append(_time)
    tloss_log.append(_tloss)
    tacc_log.append(_tacc)
    iter_log.append(epoch_cnt)

def record_valid_log(_vloss, _vacc):
    # Validation Log 기록
    vloss_log.append(_vloss)
    vacc_log.append(_vacc)

def last(log_list):
    # last 안의 마지막 숫자를 반환(print_log 함수에서 사용)
    if len(log_list) > 0:
        return log_list[len(log_list) - 1]
    else:
        return -1

def print_log():
    # 학습 추이 출력 : 소숫점 3자리까지
    train_loss = round(float(last(tloss_log)), 3)
    train_acc = round(float(last(tacc_log)), 3)
    val_loss = round(float(last(vloss_log)), 3)
    val_acc = round(float(last(vacc_log)), 3)
    time_spent = round(float(last(time_log)), 3)

    log_str = 'Epoch: {:3} | T_Loss {:5} | T_Acc {:5} | V_Loss {:5} | V_Acc {:5} | {:5}'.format(last(iter_log), train_loss, train_acc, val_loss, val_acc, time_spent)

    log_stack.append(log_str)
    
    # 학습 추이 그래프 출력
    hist_fig, loss_axis = plt.subplots(figsize=(10, 3), dpi=99)
    hist_fig.patch.set_facecolor('white')

    # Loss Line 구성
    loss_t_line = plt.plot(iter_log, tloss_log, label='Train_Loss', color='red', marker='o')
    loss_v_line = plt.plot(iter_log, vloss_log, label='Valid_Loss', color='blue', marker='s')
    loss_axis.set_xlabel('epoch')
    loss_axis.set_ylabel('loss')

    # Acc, Line 구성
    acc_axis = loss_axis.twinx()
    acc_t_line = acc_axis.plot(iter_log, tacc_log, label='Train_Acc', color='red', marker='+')
    acc_v_line = acc_axis.plot(iter_log, vacc_log, label='Valid_Acc', color='blue', marker='x')
    acc_axis.set_ylabel('accuracy')

    # 그래프 출력
    hist_lines = loss_t_line + loss_v_line + acc_t_line + acc_v_line
    loss_axis.legend(hist_lines, [l.get_label() for l in hist_lines])
    loss_axis.grid()
    plt.title('Learning history until epoch {}'.format(last(iter_log)))
    plt.draw()

    # 텍스트 로그 출력
    clear_output(wait=True)
    plt.show()
    for idx in reversed(range(len(log_stack))):
        print(log_stack[idx])

# %%
def clear_memory():
    if device != 'cpu':
        empty_cache()
    gc.collect()

# 학습 알고리즘
def epoch(data_loader, mode = 'train'):
    global epoch_cnt

    # 사용되는 변수 초기화
    iter_loss, iter_acc, last_grad_performed = [], [], False

    # 1 iteration 학습 알고리즘(for문을 나오면 1 epoch 완료)
    for _data, _label in data_loader:
        data, label = _data.to(device), _label.type(torch.LongTensor).to(device)

        # 1. Feed-forward
        if mode == 'train':
            net.train()
        else:
            # 학습때만 쓰이는 Dropout, Batch Mormalization을 미사용
            net.eval()

        result = net(data) # 1 Batch에 대한 결과가 모든 Class에 대한 확률값으로
        _, out = torch.max(result, 1) # result에서 최대 확률값을 기준으로 예측 class 도출( _ : 값 부분은 필요 없음, out : index 중 가장 큰 하나의 데이터)

        # 2. Loss 계산
        loss = loss_fn(result, label) # GT 와 Label 비교하여 Loss 산정
        iter_loss.append(loss.item()) # 학습 추이를 위하여 Loss를 기록

        # 3. 역전파 학습 후 Gradient Descent
        if mode == 'train':
            optim.zero_grad() # 미분을 통해 얻은 기울기를 초기화 for 다음 epoch
            loss.backward() # 역전파 학습
            optim.step() # Gradient Descent 수행
            last_grad_performed = True # for문을 나가면 epoch 카운터 += 1

        # 4. 정확도 계산
        acc_partial = (out == label).float().sum() # GT == Label 인 개수
        acc_partial = acc_partial / len(label) # ( TP / (TP + TM)) 해서 정확도 산출
        iter_acc.append(acc_partial.item()) # 학습 추이를 위하여 Acc. 기록

    # 역전파 학습 후 Epoch 카운터 += 1
    if last_grad_performed:
        epoch_cnt += 1

    clear_memory()

    # loss와 acc의 평균값 for 학습추이 그래프, 모든 GT와 Label 값 for 컨퓨전 매트릭스
    return np.average(iter_loss), np.average(iter_acc)

def epoch_not_finished():
    # 에폭이 끝남을 알림
    return epoch_cnt < maximum_epoch

# %% [markdown]
# - 학습 진행

# %%
# Training initialization
init_model()
init_epoch()
init_log()
maximum_epoch = EPOCH

# Training iteration

while epoch_not_finished():
    start_time = time.time()

    tloss, tacc = epoch(train_loader, mode = 'train')

    end_time = time.time()
    time_taken = end_time - start_time
    record_train_log(tloss, tacc, time_taken)

    with torch.no_grad():
        vloss, vacc = epoch(val_loader, mode = 'val')
        record_valid_log(vloss, vacc)

    print_log()

print('\n Training completed!')
# Out:
# Epoch: 700 | T_Loss 0.673 | T_Acc 0.583 | V_Loss 0.757 | V_Acc   0.5 | 1.067
# Epoch: 699 | T_Loss 0.683 | T_Acc 0.583 | V_Loss 0.758 | V_Acc   0.5 | 1.086
# Epoch: 698 | T_Loss 0.685 | T_Acc 0.583 | V_Loss  0.76 | V_Acc   0.5 | 1.051
# Epoch: 697 | T_Loss  0.69 | T_Acc 0.583 | V_Loss 0.764 | V_Acc   0.5 | 1.069
# Epoch: 696 | T_Loss 0.693 | T_Acc 0.583 | V_Loss 0.774 | V_Acc   0.5 | 1.048
# Epoch: 695 | T_Loss 0.696 | T_Acc 0.583 | V_Loss 0.785 | V_Acc   0.5 | 1.044
# Epoch: 694 | T_Loss 0.703 | T_Acc 0.583 | V_Loss 0.796 | V_Acc   0.5 | 1.064
# Epoch: 693 | T_Loss 0.771 | T_Acc 0.528 | V_Loss 0.804 | V_Acc   0.5 | 1.083
# Epoch: 692 | T_Loss 0.839 | T_Acc 0.556 | V_Loss 0.802 | V_Acc   0.5 | 1.046
# Epoch: 691 | T_Loss 0.932 | T_Acc   0.5 | V_Loss  0.82 | V_Acc   0.5 | 1.066
# Epoch: 690 | T_Loss 0.296 | T_Acc 0.889 | V_Loss  2.16 | V_Acc   0.0 | 1.042
# Epoch: 689 | T_Loss  0.71 | T_Acc  0.75 | V_Loss 0.502 | V_Acc  0.75 | 1.041
# Epoch: 688 | T_Loss 0.461 | T_Acc 0.778 | V_Loss  1.12 | V_Acc   0.5 | 1.055
# Epoch: 687 | T_Loss 0.229 | T_Acc 0.917 | V_Loss 1.475 | V_Acc  0.25 | 1.075
# Epoch: 686 | T_Loss 0.201 | T_Acc 0.944 | V_Loss 1.078 | V_Acc   0.5 | 1.038
# Epoch: 685 | T_Loss 0.207 | T_Acc 0.944 | V_Loss 1.117 | V_Acc   0.5 | 1.053
# Epoch: 684 | T_Loss 0.211 | T_Acc 0.944 | V_Loss 1.111 | V_Acc   0.5 | 1.035
# Epoch: 683 | T_Loss 0.212 | T_Acc 0.944 | V_Loss 1.102 | V_Acc   0.5 | 1.041
# Epoch: 682 | T_Loss 0.212 | T_Acc 0.944 | V_Loss 1.091 | V_Acc   0.5 | 1.039
# Epoch: 681 | T_Loss 0.211 | T_Acc 0.944 | V_Loss 1.081 | V_Acc   0.5 | 1.057
# Epoch: 680 | T_Loss 0.213 | T_Acc 0.944 | V_Loss 1.072 | V_Acc   0.5 | 1.025
# Epoch: 679 | T_Loss 0.216 | T_Acc 0.944 | V_Loss 1.061 | V_Acc   0.5 | 1.031
# Epoch: 678 | T_Loss  0.22 | T_Acc 0.944 | V_Loss  1.05 | V_Acc   0.5 | 1.044
# Epoch: 677 | T_Loss  0.22 | T_Acc 0.944 | V_Loss 1.039 | V_Acc   0.5 |  1.03
# Epoch: 676 | T_Loss 0.228 | T_Acc 0.944 | V_Loss 1.033 | V_Acc   0.5 | 1.025
# Epoch: 675 | T_Loss 0.232 | T_Acc 0.944 | V_Loss 1.035 | V_Acc   0.5 | 1.023
# Epoch: 674 | T_Loss 0.244 | T_Acc 0.944 | V_Loss 1.043 | V_Acc   0.5 | 1.035
# Epoch: 673 | T_Loss 0.252 | T_Acc 0.917 | V_Loss 1.108 | V_Acc  0.25 | 1.048
# Epoch: 672 | T_Loss 0.248 | T_Acc 0.944 | V_Loss 1.139 | V_Acc  0.25 |  1.06
# Epoch: 671 | T_Loss 0.285 | T_Acc 0.889 | V_Loss 1.115 | V_Acc  0.25 | 1.022
# Epoch: 670 | T_Loss 0.309 | T_Acc 0.889 | V_Loss 0.764 | V_Acc  0.25 | 1.014
# Epoch: 669 | T_Loss 0.271 | T_Acc 0.917 | V_Loss 0.887 | V_Acc   0.5 | 1.019
# Epoch: 668 | T_Loss 0.271 | T_Acc 0.917 | V_Loss 1.072 | V_Acc  0.25 | 1.012
# Epoch: 667 | T_Loss 0.272 | T_Acc 0.917 | V_Loss 1.055 | V_Acc   0.5 | 1.007
# Epoch: 666 | T_Loss 0.275 | T_Acc 0.917 | V_Loss 1.057 | V_Acc   0.5 | 1.007
# Epoch: 665 | T_Loss 0.277 | T_Acc 0.917 | V_Loss 1.092 | V_Acc  0.25 |  1.01
# Epoch: 664 | T_Loss 0.313 | T_Acc 0.889 | V_Loss 0.975 | V_Acc   0.5 | 1.024
# Epoch: 663 | T_Loss 0.287 | T_Acc 0.917 | V_Loss 0.901 | V_Acc   0.5 | 1.011
# Epoch: 662 | T_Loss 0.321 | T_Acc 0.889 | V_Loss 0.956 | V_Acc  0.25 | 0.989
# Epoch: 661 | T_Loss 0.308 | T_Acc 0.889 | V_Loss 1.039 | V_Acc   0.5 | 0.986
# Epoch: 660 | T_Loss 0.309 | T_Acc 0.889 | V_Loss  1.04 | V_Acc  0.25 | 0.988
# Epoch: 659 | T_Loss 0.334 | T_Acc 0.861 | V_Loss   0.7 | V_Acc  0.25 |  0.99
# Epoch: 658 | T_Loss  0.42 | T_Acc 0.833 | V_Loss 0.761 | V_Acc   0.5 | 0.986
# Epoch: 657 | T_Loss 0.362 | T_Acc 0.833 | V_Loss  0.59 | V_Acc   0.5 | 0.981
# Epoch: 656 | T_Loss 0.344 | T_Acc 0.889 | V_Loss 0.902 | V_Acc   0.5 | 0.983
# Epoch: 655 | T_Loss 0.313 | T_Acc 0.917 | V_Loss 0.939 | V_Acc  0.25 | 0.985
# Epoch: 654 | T_Loss 0.321 | T_Acc 0.889 | V_Loss 0.947 | V_Acc   0.5 | 0.984
# Epoch: 653 | T_Loss 0.329 | T_Acc 0.833 | V_Loss 0.799 | V_Acc  0.25 | 2.277
# Epoch: 652 | T_Loss 0.327 | T_Acc 0.861 | V_Loss 0.902 | V_Acc   0.5 | 0.985
# Epoch: 651 | T_Loss 0.328 | T_Acc 0.889 | V_Loss 0.826 | V_Acc  0.25 | 0.986
# Epoch: 650 | T_Loss 0.327 | T_Acc 0.861 | V_Loss 0.911 | V_Acc  0.25 | 0.985
# Epoch: 649 | T_Loss 0.335 | T_Acc 0.833 | V_Loss 0.899 | V_Acc  0.25 | 0.982
# Epoch: 648 | T_Loss 0.342 | T_Acc 0.806 | V_Loss 0.793 | V_Acc  0.25 | 0.982
# Epoch: 647 | T_Loss 0.354 | T_Acc 0.778 | V_Loss 0.878 | V_Acc   0.5 | 0.981
# Epoch: 646 | T_Loss 0.352 | T_Acc 0.694 | V_Loss 0.799 | V_Acc  0.25 | 0.979
# Epoch: 645 | T_Loss 0.344 | T_Acc 0.861 | V_Loss 0.831 | V_Acc   0.5 | 0.977
# Epoch: 644 | T_Loss 0.345 | T_Acc 0.861 | V_Loss 0.809 | V_Acc   0.5 | 0.977
# Epoch: 643 | T_Loss 0.358 | T_Acc 0.833 | V_Loss 0.792 | V_Acc   0.5 | 0.976
# Epoch: 642 | T_Loss 0.362 | T_Acc 0.722 | V_Loss 0.786 | V_Acc  0.75 | 0.973
# Epoch: 641 | T_Loss 0.366 | T_Acc 0.722 | V_Loss 0.744 | V_Acc  0.75 | 0.973
# Epoch: 640 | T_Loss 0.374 | T_Acc 0.694 | V_Loss 0.727 | V_Acc  0.75 | 0.971
# Epoch: 639 | T_Loss 0.391 | T_Acc 0.694 | V_Loss 0.701 | V_Acc  0.75 |  0.97
# Epoch: 638 | T_Loss 0.386 | T_Acc 0.722 | V_Loss  0.69 | V_Acc  0.75 | 0.968
# Epoch: 637 | T_Loss 0.395 | T_Acc 0.722 | V_Loss 0.692 | V_Acc  0.75 | 0.968
# Epoch: 636 | T_Loss 0.416 | T_Acc 0.694 | V_Loss 0.674 | V_Acc  0.75 | 0.967
# Epoch: 635 | T_Loss 0.411 | T_Acc 0.722 | V_Loss 0.668 | V_Acc  0.75 | 0.964
# Epoch: 634 | T_Loss 0.415 | T_Acc 0.722 | V_Loss 0.656 | V_Acc  0.75 | 0.966
# Epoch: 633 | T_Loss 0.435 | T_Acc  0.75 | V_Loss 0.648 | V_Acc  0.75 | 0.961
# Epoch: 632 | T_Loss 0.435 | T_Acc 0.667 | V_Loss 0.631 | V_Acc  0.75 | 0.954
# Epoch: 631 | T_Loss 0.451 | T_Acc  0.75 | V_Loss 0.633 | V_Acc  0.75 |  0.96
# Epoch: 630 | T_Loss 0.456 | T_Acc 0.694 | V_Loss  0.62 | V_Acc  0.75 | 0.957
# Epoch: 629 | T_Loss 0.503 | T_Acc 0.694 | V_Loss 0.554 | V_Acc  0.75 | 0.957
# Epoch: 628 | T_Loss 0.641 | T_Acc 0.639 | V_Loss 0.481 | V_Acc  0.75 | 0.956
# Epoch: 627 | T_Loss 0.749 | T_Acc 0.611 | V_Loss 0.334 | V_Acc  0.75 | 0.954
# Epoch: 626 | T_Loss 0.573 | T_Acc 0.722 | V_Loss 0.279 | V_Acc  0.75 | 0.953
# Epoch: 625 | T_Loss 0.603 | T_Acc 0.861 | V_Loss 0.903 | V_Acc   0.5 | 0.951
# Epoch: 624 | T_Loss 0.496 | T_Acc  0.75 | V_Loss  1.16 | V_Acc  0.25 | 0.943
# Epoch: 623 | T_Loss  0.31 | T_Acc 0.861 | V_Loss 1.279 | V_Acc   0.5 | 0.933
# Epoch: 622 | T_Loss 0.275 | T_Acc 0.861 | V_Loss 1.265 | V_Acc   0.5 | 0.945
# Epoch: 621 | T_Loss 0.159 | T_Acc 0.889 | V_Loss 1.256 | V_Acc   0.5 | 0.936
# Epoch: 620 | T_Loss 0.146 | T_Acc 0.889 | V_Loss 1.309 | V_Acc   0.5 | 0.931
# Epoch: 619 | T_Loss 0.145 | T_Acc 0.889 | V_Loss 1.353 | V_Acc   0.5 | 0.936
# Epoch: 618 | T_Loss 0.148 | T_Acc 0.889 | V_Loss 1.407 | V_Acc   0.5 | 0.924
# Epoch: 617 | T_Loss 0.147 | T_Acc 0.889 | V_Loss 1.338 | V_Acc   0.5 | 0.937
# Epoch: 616 | T_Loss 0.152 | T_Acc 0.889 | V_Loss 1.375 | V_Acc   0.5 | 0.945
# Epoch: 615 | T_Loss 0.154 | T_Acc 0.889 | V_Loss 1.395 | V_Acc   0.5 | 1.009
# Epoch: 614 | T_Loss 0.158 | T_Acc 0.889 | V_Loss 1.384 | V_Acc   0.5 | 0.934
# Epoch: 613 | T_Loss 0.157 | T_Acc 0.889 | V_Loss 1.394 | V_Acc   0.5 | 0.944
# Epoch: 612 | T_Loss 0.158 | T_Acc 0.889 | V_Loss  1.39 | V_Acc   0.5 | 0.962
# Epoch: 611 | T_Loss 0.166 | T_Acc 0.889 | V_Loss  1.39 | V_Acc   0.5 | 0.986
# Epoch: 610 | T_Loss  0.17 | T_Acc 0.889 | V_Loss 1.385 | V_Acc   0.5 | 0.983
# Epoch: 609 | T_Loss  0.17 | T_Acc 0.889 | V_Loss 1.383 | V_Acc   0.5 | 0.981
# Epoch: 608 | T_Loss 0.176 | T_Acc 0.889 | V_Loss 1.395 | V_Acc   0.5 | 0.935
# Epoch: 607 | T_Loss 0.181 | T_Acc 0.889 | V_Loss 1.381 | V_Acc   0.5 | 0.927
# Epoch: 606 | T_Loss  0.18 | T_Acc 0.889 | V_Loss 1.394 | V_Acc   0.5 | 0.952
# Epoch: 605 | T_Loss 0.185 | T_Acc 0.889 | V_Loss   1.4 | V_Acc   0.5 | 0.943
# Epoch: 604 | T_Loss 0.194 | T_Acc 0.889 | V_Loss 1.389 | V_Acc   0.5 | 0.931
# Epoch: 603 | T_Loss 0.193 | T_Acc 0.889 | V_Loss 1.385 | V_Acc   0.5 | 0.925
# Epoch: 602 | T_Loss 0.206 | T_Acc 0.889 | V_Loss 1.388 | V_Acc   0.5 | 0.931
# Epoch: 601 | T_Loss 0.201 | T_Acc 0.889 | V_Loss 1.389 | V_Acc   0.5 |  0.92
# Epoch: 600 | T_Loss 0.209 | T_Acc 0.889 | V_Loss 1.398 | V_Acc   0.5 | 0.917
# Epoch: 599 | T_Loss  0.21 | T_Acc 0.889 | V_Loss 1.386 | V_Acc   0.5 | 0.915
# Epoch: 598 | T_Loss 0.219 | T_Acc 0.889 | V_Loss 1.381 | V_Acc   0.5 | 0.925
# Epoch: 597 | T_Loss 0.223 | T_Acc 0.889 | V_Loss 1.382 | V_Acc   0.5 | 0.972
# Epoch: 596 | T_Loss 0.231 | T_Acc 0.889 | V_Loss 1.371 | V_Acc   0.5 | 0.971
# Epoch: 595 | T_Loss 0.237 | T_Acc 0.861 | V_Loss  1.38 | V_Acc   0.5 | 0.972
# Epoch: 594 | T_Loss 0.242 | T_Acc 0.861 | V_Loss 1.392 | V_Acc   0.5 | 0.968
# Epoch: 593 | T_Loss 0.272 | T_Acc 0.861 | V_Loss 1.379 | V_Acc   0.5 | 0.967
# Epoch: 592 | T_Loss 0.279 | T_Acc 0.861 | V_Loss 1.334 | V_Acc   0.5 | 0.968
# Epoch: 591 | T_Loss 0.316 | T_Acc 0.861 | V_Loss 1.127 | V_Acc   0.5 | 0.963
# Epoch: 590 | T_Loss 0.285 | T_Acc 0.861 | V_Loss 0.981 | V_Acc   0.5 | 0.962
# Epoch: 589 | T_Loss 0.295 | T_Acc 0.861 | V_Loss 1.328 | V_Acc   0.5 | 0.959
# Epoch: 588 | T_Loss 0.266 | T_Acc 0.889 | V_Loss 0.977 | V_Acc   0.5 |  0.96
# Epoch: 587 | T_Loss 0.294 | T_Acc 0.861 | V_Loss 1.109 | V_Acc   0.5 | 0.951
# Epoch: 586 | T_Loss 0.307 | T_Acc 0.861 | V_Loss 1.064 | V_Acc   0.5 | 0.958
# Epoch: 585 | T_Loss 0.324 | T_Acc 0.861 | V_Loss 1.025 | V_Acc   0.5 | 0.937
# Epoch: 584 | T_Loss 0.321 | T_Acc 0.833 | V_Loss 1.224 | V_Acc   0.5 | 0.954
# Epoch: 583 | T_Loss 0.331 | T_Acc 0.833 | V_Loss 1.215 | V_Acc   0.5 |  0.92
# Epoch: 582 | T_Loss 0.344 | T_Acc 0.806 | V_Loss 1.159 | V_Acc   0.5 | 0.929
# Epoch: 581 | T_Loss 0.356 | T_Acc 0.806 | V_Loss 1.146 | V_Acc   0.5 | 0.896
# Epoch: 580 | T_Loss 0.359 | T_Acc 0.806 | V_Loss 1.128 | V_Acc   0.5 | 0.889
# Epoch: 579 | T_Loss 0.365 | T_Acc 0.806 | V_Loss  1.09 | V_Acc   0.5 | 0.898
# Epoch: 578 | T_Loss 0.365 | T_Acc 0.806 | V_Loss 1.082 | V_Acc   0.5 | 0.886
# Epoch: 577 | T_Loss 0.371 | T_Acc 0.806 | V_Loss 1.081 | V_Acc   0.5 | 0.874
# Epoch: 576 | T_Loss 0.374 | T_Acc 0.806 | V_Loss 1.078 | V_Acc   0.5 |  0.87
# Epoch: 575 | T_Loss 0.374 | T_Acc 0.806 | V_Loss 1.066 | V_Acc   0.5 | 0.884
# Epoch: 574 | T_Loss 0.376 | T_Acc 0.806 | V_Loss 1.052 | V_Acc   0.5 | 0.883
# Epoch: 573 | T_Loss 0.384 | T_Acc 0.806 | V_Loss 1.039 | V_Acc   0.5 | 0.884
# Epoch: 572 | T_Loss 0.395 | T_Acc 0.806 | V_Loss 1.022 | V_Acc   0.5 | 0.868
# Epoch: 571 | T_Loss 0.393 | T_Acc 0.806 | V_Loss 1.016 | V_Acc   0.5 | 0.866
# Epoch: 570 | T_Loss 0.399 | T_Acc 0.806 | V_Loss 1.011 | V_Acc   0.5 | 0.865
# Epoch: 569 | T_Loss 0.402 | T_Acc 0.806 | V_Loss 1.003 | V_Acc   0.5 | 0.876
# Epoch: 568 | T_Loss 0.411 | T_Acc 0.806 | V_Loss 0.992 | V_Acc   0.5 | 0.877
# Epoch: 567 | T_Loss 0.408 | T_Acc 0.806 | V_Loss 0.981 | V_Acc   0.5 | 0.875
# Epoch: 566 | T_Loss 0.415 | T_Acc 0.806 | V_Loss 0.982 | V_Acc   0.5 | 0.873
# Epoch: 565 | T_Loss 0.418 | T_Acc 0.806 | V_Loss 0.978 | V_Acc   0.5 | 0.872
# Epoch: 564 | T_Loss  0.42 | T_Acc 0.806 | V_Loss 0.979 | V_Acc   0.5 | 0.871
# Epoch: 563 | T_Loss 0.431 | T_Acc 0.806 | V_Loss 0.983 | V_Acc   0.5 |  0.87
# Epoch: 562 | T_Loss 0.441 | T_Acc 0.806 | V_Loss 0.993 | V_Acc   0.5 | 0.855
# Epoch: 561 | T_Loss  0.45 | T_Acc 0.806 | V_Loss 1.002 | V_Acc   0.5 | 0.855
# Epoch: 560 | T_Loss 0.484 | T_Acc 0.806 | V_Loss 1.005 | V_Acc   0.5 | 0.865
# Epoch: 559 | T_Loss 0.509 | T_Acc 0.778 | V_Loss 1.023 | V_Acc   0.5 | 0.853
# Epoch: 558 | T_Loss 0.611 | T_Acc 0.722 | V_Loss 1.066 | V_Acc   0.5 | 0.854
# Epoch: 557 | T_Loss 0.685 | T_Acc 0.722 | V_Loss 1.096 | V_Acc   0.5 | 0.861
# Epoch: 556 | T_Loss 0.756 | T_Acc 0.694 | V_Loss 1.185 | V_Acc   0.5 | 0.861
# Epoch: 555 | T_Loss 0.902 | T_Acc 0.639 | V_Loss 0.929 | V_Acc   0.5 | 0.859
# Epoch: 554 | T_Loss 0.896 | T_Acc 0.694 | V_Loss 1.362 | V_Acc   0.5 | 0.855
# Epoch: 553 | T_Loss 0.782 | T_Acc 0.722 | V_Loss 2.102 | V_Acc  0.25 | 0.856
# Epoch: 552 | T_Loss  1.21 | T_Acc 0.611 | V_Loss 1.508 | V_Acc  0.25 | 0.855
# Epoch: 551 | T_Loss 0.925 | T_Acc 0.722 | V_Loss 1.818 | V_Acc  0.25 | 0.853
# Epoch: 550 | T_Loss 0.494 | T_Acc 0.833 | V_Loss 1.326 | V_Acc  0.25 | 0.842
# Epoch: 549 | T_Loss 0.099 | T_Acc 0.972 | V_Loss 1.904 | V_Acc  0.25 | 0.851
# Epoch: 548 | T_Loss 0.105 | T_Acc 0.972 | V_Loss 1.902 | V_Acc  0.25 |  0.85
# Epoch: 547 | T_Loss 0.103 | T_Acc 0.972 | V_Loss 1.877 | V_Acc  0.25 | 0.849
# Epoch: 546 | T_Loss 0.103 | T_Acc 0.972 | V_Loss 1.865 | V_Acc  0.25 | 0.847
# Epoch: 545 | T_Loss 0.108 | T_Acc 0.972 | V_Loss 1.841 | V_Acc  0.25 | 0.845
# Epoch: 544 | T_Loss 0.102 | T_Acc 0.972 | V_Loss 1.836 | V_Acc  0.25 | 0.845
# Epoch: 543 | T_Loss 0.121 | T_Acc 0.972 | V_Loss  1.81 | V_Acc  0.25 | 0.844
# Epoch: 542 | T_Loss 0.105 | T_Acc 0.972 | V_Loss 1.811 | V_Acc  0.25 | 0.841
# Epoch: 541 | T_Loss 0.118 | T_Acc 0.972 | V_Loss 1.798 | V_Acc  0.25 |  0.83
# Epoch: 540 | T_Loss 0.121 | T_Acc 0.972 | V_Loss 1.794 | V_Acc  0.25 | 0.832
# Epoch: 539 | T_Loss  0.14 | T_Acc 0.944 | V_Loss 1.786 | V_Acc  0.25 | 0.821
# Epoch: 538 | T_Loss 0.134 | T_Acc 0.944 | V_Loss 1.779 | V_Acc  0.25 | 0.837
# Epoch: 537 | T_Loss 0.161 | T_Acc 0.944 | V_Loss 1.767 | V_Acc  0.25 | 0.836
# Epoch: 536 | T_Loss 0.155 | T_Acc 0.944 | V_Loss 1.761 | V_Acc  0.25 | 0.829
# Epoch: 535 | T_Loss 0.164 | T_Acc 0.944 | V_Loss 1.743 | V_Acc  0.25 | 0.833
# Epoch: 534 | T_Loss 0.173 | T_Acc 0.944 | V_Loss 1.732 | V_Acc  0.25 | 0.832
# Epoch: 533 | T_Loss 0.175 | T_Acc 0.944 | V_Loss 1.729 | V_Acc  0.25 | 0.832
# Epoch: 532 | T_Loss 0.179 | T_Acc 0.944 | V_Loss  1.73 | V_Acc  0.25 |  0.83
# Epoch: 531 | T_Loss 0.176 | T_Acc 0.944 | V_Loss 1.732 | V_Acc  0.25 | 0.828
# Epoch: 530 | T_Loss 0.176 | T_Acc 0.944 | V_Loss  1.73 | V_Acc  0.25 | 0.813
# Epoch: 529 | T_Loss  0.18 | T_Acc 0.944 | V_Loss 1.729 | V_Acc  0.25 | 0.826
# Epoch: 528 | T_Loss 0.175 | T_Acc 0.944 | V_Loss 1.724 | V_Acc  0.25 | 0.824
# Epoch: 527 | T_Loss 0.185 | T_Acc 0.944 | V_Loss 1.726 | V_Acc  0.25 | 0.813
# Epoch: 526 | T_Loss 0.182 | T_Acc 0.944 | V_Loss 1.731 | V_Acc  0.25 | 0.822
# Epoch: 525 | T_Loss 0.182 | T_Acc 0.944 | V_Loss 1.739 | V_Acc  0.25 | 0.811
# Epoch: 524 | T_Loss 0.183 | T_Acc 0.944 | V_Loss 1.747 | V_Acc  0.25 | 0.809
# Epoch: 523 | T_Loss 0.183 | T_Acc 0.944 | V_Loss 1.756 | V_Acc  0.25 | 0.805
# Epoch: 522 | T_Loss 0.184 | T_Acc 0.944 | V_Loss 1.767 | V_Acc  0.25 | 0.817
# Epoch: 521 | T_Loss 0.184 | T_Acc 0.944 | V_Loss 1.774 | V_Acc  0.25 | 0.802
# Epoch: 520 | T_Loss 0.188 | T_Acc 0.944 | V_Loss 1.774 | V_Acc  0.25 | 0.801
# Epoch: 519 | T_Loss 0.187 | T_Acc 0.944 | V_Loss 1.771 | V_Acc  0.25 | 0.813
# Epoch: 518 | T_Loss 0.198 | T_Acc 0.944 | V_Loss 1.762 | V_Acc  0.25 | 0.812
# Epoch: 517 | T_Loss 0.203 | T_Acc 0.944 | V_Loss 1.749 | V_Acc  0.25 |  0.81
# Epoch: 516 | T_Loss 0.213 | T_Acc 0.944 | V_Loss 1.734 | V_Acc  0.25 |  0.81
# Epoch: 515 | T_Loss 0.231 | T_Acc 0.944 | V_Loss 1.708 | V_Acc  0.25 | 0.808
# Epoch: 514 | T_Loss 0.239 | T_Acc 0.917 | V_Loss 1.687 | V_Acc  0.25 | 0.802
# Epoch: 513 | T_Loss 0.259 | T_Acc 0.917 | V_Loss 1.683 | V_Acc  0.25 | 0.804
# Epoch: 512 | T_Loss 0.255 | T_Acc 0.917 | V_Loss 1.669 | V_Acc  0.25 |   0.8
# Epoch: 511 | T_Loss 0.249 | T_Acc 0.917 | V_Loss 1.657 | V_Acc  0.25 | 0.802
# Epoch: 510 | T_Loss 0.273 | T_Acc 0.917 | V_Loss 1.664 | V_Acc  0.25 | 0.801
# Epoch: 509 | T_Loss 0.285 | T_Acc 0.889 | V_Loss 2.032 | V_Acc  0.25 | 0.784
# Epoch: 508 | T_Loss 0.326 | T_Acc 0.861 | V_Loss 1.989 | V_Acc  0.25 | 0.799
# Epoch: 507 | T_Loss  0.41 | T_Acc 0.889 | V_Loss 1.617 | V_Acc  0.25 | 0.799
# Epoch: 506 | T_Loss 0.243 | T_Acc 0.917 | V_Loss  1.63 | V_Acc  0.25 | 0.795
# Epoch: 505 | T_Loss 0.287 | T_Acc 0.917 | V_Loss 1.672 | V_Acc  0.25 | 0.794
# Epoch: 504 | T_Loss 0.248 | T_Acc 0.917 | V_Loss  1.67 | V_Acc  0.25 | 0.794
# Epoch: 503 | T_Loss 0.237 | T_Acc 0.917 | V_Loss  1.61 | V_Acc  0.25 | 0.792
# Epoch: 502 | T_Loss 0.237 | T_Acc 0.917 | V_Loss 1.626 | V_Acc  0.25 | 0.791
# Epoch: 501 | T_Loss 0.238 | T_Acc 0.917 | V_Loss 1.628 | V_Acc  0.25 | 0.775
# Epoch: 500 | T_Loss 0.242 | T_Acc 0.917 | V_Loss 1.627 | V_Acc  0.25 | 0.788
# Epoch: 499 | T_Loss 0.245 | T_Acc 0.917 | V_Loss 1.617 | V_Acc  0.25 | 0.787
# Epoch: 498 | T_Loss 0.242 | T_Acc 0.917 | V_Loss 1.613 | V_Acc  0.25 | 0.785
# Epoch: 497 | T_Loss 0.246 | T_Acc 0.917 | V_Loss 1.612 | V_Acc  0.25 | 0.775
# Epoch: 496 | T_Loss 0.251 | T_Acc 0.917 | V_Loss 1.605 | V_Acc  0.25 | 0.771
# Epoch: 495 | T_Loss 0.248 | T_Acc 0.917 | V_Loss 1.603 | V_Acc  0.25 |  0.77
# Epoch: 494 | T_Loss 0.248 | T_Acc 0.917 | V_Loss 1.598 | V_Acc  0.25 | 0.765
# Epoch: 493 | T_Loss 0.252 | T_Acc 0.917 | V_Loss 1.591 | V_Acc  0.25 | 0.762
# Epoch: 492 | T_Loss 0.248 | T_Acc 0.917 | V_Loss 1.584 | V_Acc  0.25 | 0.758
# Epoch: 491 | T_Loss 0.247 | T_Acc 0.917 | V_Loss 1.583 | V_Acc  0.25 | 0.776
# Epoch: 490 | T_Loss 0.249 | T_Acc 0.917 | V_Loss 1.586 | V_Acc  0.25 | 0.774
# Epoch: 489 | T_Loss  0.25 | T_Acc 0.917 | V_Loss  1.86 | V_Acc  0.25 |  0.77
# Epoch: 488 | T_Loss 0.255 | T_Acc 0.917 | V_Loss 1.949 | V_Acc  0.25 | 0.767
# Epoch: 487 | T_Loss 0.253 | T_Acc 0.917 | V_Loss 1.915 | V_Acc  0.25 | 2.345
# Epoch: 486 | T_Loss 0.255 | T_Acc 0.917 | V_Loss  1.88 | V_Acc  0.25 | 0.809
# Epoch: 485 | T_Loss 0.257 | T_Acc 0.917 | V_Loss 1.825 | V_Acc  0.25 | 0.761
# Epoch: 484 | T_Loss 0.256 | T_Acc 0.917 | V_Loss 1.772 | V_Acc  0.25 | 0.795
# Epoch: 483 | T_Loss 0.261 | T_Acc 0.917 | V_Loss 1.749 | V_Acc  0.25 | 0.795
# Epoch: 482 | T_Loss 0.258 | T_Acc 0.917 | V_Loss 1.741 | V_Acc  0.25 | 0.749
# Epoch: 481 | T_Loss 0.256 | T_Acc 0.917 | V_Loss 1.729 | V_Acc  0.25 | 0.804
# Epoch: 480 | T_Loss 0.259 | T_Acc 0.917 | V_Loss 1.716 | V_Acc  0.25 | 0.769
# Epoch: 479 | T_Loss 0.261 | T_Acc 0.917 | V_Loss  1.71 | V_Acc  0.25 | 0.806
# Epoch: 478 | T_Loss 0.262 | T_Acc 0.917 | V_Loss 1.706 | V_Acc  0.25 | 0.787
# Epoch: 477 | T_Loss 0.263 | T_Acc 0.917 | V_Loss 1.703 | V_Acc  0.25 |  0.75
# Epoch: 476 | T_Loss 0.267 | T_Acc 0.917 | V_Loss 1.702 | V_Acc  0.25 | 0.803
# Epoch: 475 | T_Loss 0.264 | T_Acc 0.917 | V_Loss 1.702 | V_Acc  0.25 |  0.77
# Epoch: 474 | T_Loss 0.264 | T_Acc 0.917 | V_Loss 1.703 | V_Acc  0.25 | 0.798
# Epoch: 473 | T_Loss 0.266 | T_Acc 0.917 | V_Loss 1.705 | V_Acc  0.25 | 0.791
# Epoch: 472 | T_Loss 0.264 | T_Acc 0.917 | V_Loss 1.708 | V_Acc  0.25 | 0.754
# Epoch: 471 | T_Loss 0.267 | T_Acc 0.917 | V_Loss 1.709 | V_Acc  0.25 | 0.764
# Epoch: 470 | T_Loss 0.268 | T_Acc 0.917 | V_Loss  1.71 | V_Acc  0.25 | 0.768
# Epoch: 469 | T_Loss 0.273 | T_Acc 0.917 | V_Loss 1.712 | V_Acc  0.25 | 0.791
# Epoch: 468 | T_Loss 0.272 | T_Acc 0.917 | V_Loss 1.716 | V_Acc  0.25 | 0.777
# Epoch: 467 | T_Loss 0.274 | T_Acc 0.917 | V_Loss 1.717 | V_Acc  0.25 | 0.735
# Epoch: 466 | T_Loss 0.274 | T_Acc 0.917 | V_Loss 1.716 | V_Acc  0.25 | 0.787
# Epoch: 465 | T_Loss 0.273 | T_Acc 0.917 | V_Loss 1.715 | V_Acc  0.25 | 0.747
# Epoch: 464 | T_Loss 0.275 | T_Acc 0.917 | V_Loss 1.716 | V_Acc  0.25 | 0.763
# Epoch: 463 | T_Loss 0.287 | T_Acc 0.917 | V_Loss  1.72 | V_Acc  0.25 | 0.757
# Epoch: 462 | T_Loss 0.283 | T_Acc 0.917 | V_Loss 1.729 | V_Acc  0.25 | 0.781
# Epoch: 461 | T_Loss  0.28 | T_Acc 0.944 | V_Loss 1.819 | V_Acc  0.25 | 0.767
# Epoch: 460 | T_Loss  0.29 | T_Acc 0.861 | V_Loss 1.844 | V_Acc  0.25 | 0.722
# Epoch: 459 | T_Loss 0.292 | T_Acc 0.861 | V_Loss 1.818 | V_Acc  0.25 | 0.777
# Epoch: 458 | T_Loss 0.301 | T_Acc 0.861 | V_Loss 1.799 | V_Acc  0.25 |  0.73
# Epoch: 457 | T_Loss 0.301 | T_Acc 0.861 | V_Loss 1.791 | V_Acc  0.25 | 0.774
# Epoch: 456 | T_Loss   0.3 | T_Acc 0.861 | V_Loss 1.765 | V_Acc  0.25 | 0.741
# Epoch: 455 | T_Loss 0.307 | T_Acc 0.861 | V_Loss 1.714 | V_Acc  0.25 | 0.725
# Epoch: 454 | T_Loss 0.313 | T_Acc 0.861 | V_Loss 1.689 | V_Acc  0.25 | 0.742
# Epoch: 453 | T_Loss 0.316 | T_Acc 0.833 | V_Loss 1.674 | V_Acc  0.25 | 0.768
# Epoch: 452 | T_Loss 0.314 | T_Acc 0.861 | V_Loss 1.665 | V_Acc  0.25 | 0.741
# Epoch: 451 | T_Loss 0.388 | T_Acc 0.806 | V_Loss 1.672 | V_Acc  0.25 | 0.768
# Epoch: 450 | T_Loss 0.324 | T_Acc 0.833 | V_Loss 1.661 | V_Acc  0.25 | 0.748
# Epoch: 449 | T_Loss 0.316 | T_Acc 0.861 | V_Loss 1.648 | V_Acc  0.25 | 0.763
# Epoch: 448 | T_Loss  0.31 | T_Acc 0.861 | V_Loss 1.649 | V_Acc  0.25 | 0.714
# Epoch: 447 | T_Loss 0.318 | T_Acc 0.861 | V_Loss 1.636 | V_Acc  0.25 | 0.714
# Epoch: 446 | T_Loss 0.328 | T_Acc 0.861 | V_Loss 1.617 | V_Acc  0.25 | 0.752
# Epoch: 445 | T_Loss  0.32 | T_Acc 0.861 | V_Loss 1.598 | V_Acc  0.25 | 0.705
# Epoch: 444 | T_Loss 0.362 | T_Acc 0.833 | V_Loss 1.582 | V_Acc  0.25 | 0.751
# Epoch: 443 | T_Loss 0.369 | T_Acc 0.833 | V_Loss 1.551 | V_Acc  0.25 | 0.705
# Epoch: 442 | T_Loss 0.333 | T_Acc 0.861 | V_Loss 1.536 | V_Acc  0.25 | 0.747
# Epoch: 441 | T_Loss 0.353 | T_Acc 0.833 | V_Loss 1.515 | V_Acc  0.25 | 0.699
# Epoch: 440 | T_Loss 0.369 | T_Acc 0.833 | V_Loss 1.488 | V_Acc  0.25 | 0.748
# Epoch: 439 | T_Loss 0.372 | T_Acc 0.833 | V_Loss  1.47 | V_Acc  0.25 | 0.699
# Epoch: 438 | T_Loss 0.381 | T_Acc 0.833 | V_Loss 1.452 | V_Acc  0.25 | 0.747
# Epoch: 437 | T_Loss 0.387 | T_Acc 0.833 | V_Loss 1.417 | V_Acc  0.25 | 0.693
# Epoch: 436 | T_Loss 0.392 | T_Acc 0.833 | V_Loss 1.363 | V_Acc  0.25 | 0.742
# Epoch: 435 | T_Loss 0.399 | T_Acc 0.833 | V_Loss 1.315 | V_Acc  0.25 | 0.693
# Epoch: 434 | T_Loss 0.406 | T_Acc 0.833 | V_Loss  1.32 | V_Acc  0.25 | 0.739
# Epoch: 433 | T_Loss 0.414 | T_Acc 0.806 | V_Loss  1.33 | V_Acc  0.25 | 0.688
# Epoch: 432 | T_Loss 0.446 | T_Acc 0.778 | V_Loss 1.288 | V_Acc  0.25 | 0.699
# Epoch: 431 | T_Loss 0.459 | T_Acc 0.806 | V_Loss 1.158 | V_Acc  0.25 | 0.722
# Epoch: 430 | T_Loss  0.51 | T_Acc  0.75 | V_Loss 1.131 | V_Acc  0.25 | 0.724
# Epoch: 429 | T_Loss 0.578 | T_Acc 0.667 | V_Loss 1.146 | V_Acc   0.5 | 0.738
# Epoch: 428 | T_Loss 0.657 | T_Acc 0.611 | V_Loss  0.65 | V_Acc  0.75 | 0.719
# Epoch: 427 | T_Loss 0.651 | T_Acc 0.667 | V_Loss  0.72 | V_Acc  0.75 | 0.733
# Epoch: 426 | T_Loss 0.692 | T_Acc 0.528 | V_Loss 0.699 | V_Acc  0.75 | 0.708
# Epoch: 425 | T_Loss 0.616 | T_Acc 0.694 | V_Loss 0.725 | V_Acc  0.75 |  0.73
# Epoch: 424 | T_Loss 0.541 | T_Acc 0.722 | V_Loss 1.067 | V_Acc   0.5 | 0.693
# Epoch: 423 | T_Loss  0.45 | T_Acc 0.806 | V_Loss 1.314 | V_Acc  0.25 | 0.682
# Epoch: 422 | T_Loss 0.559 | T_Acc 0.694 | V_Loss 1.241 | V_Acc  0.25 | 0.679
# Epoch: 421 | T_Loss 0.713 | T_Acc 0.611 | V_Loss 1.204 | V_Acc  0.25 | 0.721
# Epoch: 420 | T_Loss 0.459 | T_Acc 0.778 | V_Loss 1.252 | V_Acc  0.25 | 0.682
# Epoch: 419 | T_Loss 0.472 | T_Acc 0.778 | V_Loss 1.231 | V_Acc  0.25 | 0.708
# Epoch: 418 | T_Loss 0.476 | T_Acc 0.778 | V_Loss 1.233 | V_Acc  0.25 | 0.716
# Epoch: 417 | T_Loss  0.49 | T_Acc 0.778 | V_Loss  1.25 | V_Acc  0.25 | 0.694
# Epoch: 416 | T_Loss 0.493 | T_Acc 0.778 | V_Loss 1.254 | V_Acc  0.25 | 0.718
# Epoch: 415 | T_Loss 0.494 | T_Acc  0.75 | V_Loss 1.247 | V_Acc  0.25 | 0.679
# Epoch: 414 | T_Loss 0.492 | T_Acc  0.75 | V_Loss 1.237 | V_Acc  0.25 | 0.684
# Epoch: 413 | T_Loss 0.498 | T_Acc  0.75 | V_Loss 1.243 | V_Acc  0.25 |  0.66
# Epoch: 412 | T_Loss 0.506 | T_Acc  0.75 | V_Loss  1.24 | V_Acc  0.25 |   0.7
# Epoch: 411 | T_Loss 0.503 | T_Acc  0.75 | V_Loss 1.232 | V_Acc  0.25 | 0.713
# Epoch: 410 | T_Loss 0.513 | T_Acc  0.75 | V_Loss 1.229 | V_Acc  0.25 | 0.686
# Epoch: 409 | T_Loss 0.521 | T_Acc  0.75 | V_Loss 1.224 | V_Acc  0.25 | 0.669
# Epoch: 408 | T_Loss 0.525 | T_Acc  0.75 | V_Loss 1.217 | V_Acc  0.25 | 0.658
# Epoch: 407 | T_Loss 0.531 | T_Acc  0.75 | V_Loss 1.209 | V_Acc  0.25 | 0.699
# Epoch: 406 | T_Loss 0.543 | T_Acc  0.75 | V_Loss   1.2 | V_Acc  0.25 | 0.655
# Epoch: 405 | T_Loss 0.549 | T_Acc  0.75 | V_Loss 1.188 | V_Acc  0.25 | 0.681
# Epoch: 404 | T_Loss 0.591 | T_Acc 0.694 | V_Loss 1.183 | V_Acc  0.25 | 0.684
# Epoch: 403 | T_Loss 0.572 | T_Acc 0.694 | V_Loss 1.187 | V_Acc  0.25 | 0.659
# Epoch: 402 | T_Loss 0.557 | T_Acc  0.75 | V_Loss 1.182 | V_Acc  0.25 | 0.696
# Epoch: 401 | T_Loss 0.585 | T_Acc  0.75 | V_Loss 1.177 | V_Acc  0.25 | 0.699
# Epoch: 400 | T_Loss 0.582 | T_Acc 0.667 | V_Loss 1.182 | V_Acc  0.25 | 0.677
# Epoch: 399 | T_Loss 0.596 | T_Acc 0.694 | V_Loss 1.179 | V_Acc   0.5 | 0.695
# Epoch: 398 | T_Loss 0.652 | T_Acc 0.639 | V_Loss 1.192 | V_Acc  0.25 | 0.653
# Epoch: 397 | T_Loss 0.689 | T_Acc 0.556 | V_Loss 1.244 | V_Acc  0.25 | 0.688
# Epoch: 396 | T_Loss 0.699 | T_Acc 0.528 | V_Loss 1.014 | V_Acc   0.5 |  0.69
# Epoch: 395 | T_Loss 0.606 | T_Acc 0.639 | V_Loss 0.973 | V_Acc   0.5 | 0.669
# Epoch: 394 | T_Loss  0.54 | T_Acc 0.667 | V_Loss 1.254 | V_Acc  0.25 | 0.689
# Epoch: 393 | T_Loss 0.547 | T_Acc 0.722 | V_Loss 1.224 | V_Acc  0.25 | 0.641
# Epoch: 392 | T_Loss 0.528 | T_Acc 0.694 | V_Loss 1.224 | V_Acc  0.25 | 0.678
# Epoch: 391 | T_Loss 0.544 | T_Acc 0.667 | V_Loss 1.198 | V_Acc  0.25 | 0.685
# Epoch: 390 | T_Loss 0.556 | T_Acc 0.639 | V_Loss 1.187 | V_Acc  0.25 | 0.655
# Epoch: 389 | T_Loss 0.565 | T_Acc 0.583 | V_Loss 1.169 | V_Acc  0.25 | 0.638
# Epoch: 388 | T_Loss 0.577 | T_Acc 0.611 | V_Loss 1.145 | V_Acc  0.25 | 0.666
# Epoch: 387 | T_Loss 0.584 | T_Acc 0.583 | V_Loss 1.104 | V_Acc  0.25 | 0.666
# Epoch: 386 | T_Loss 0.589 | T_Acc 0.694 | V_Loss 1.051 | V_Acc  0.25 | 0.642
# Epoch: 385 | T_Loss 0.597 | T_Acc 0.694 | V_Loss 1.003 | V_Acc  0.25 | 0.629
# Epoch: 384 | T_Loss 0.599 | T_Acc 0.694 | V_Loss 0.967 | V_Acc  0.25 | 0.663
# Epoch: 383 | T_Loss 0.602 | T_Acc 0.694 | V_Loss 0.933 | V_Acc  0.25 | 0.644
# Epoch: 382 | T_Loss 0.606 | T_Acc 0.667 | V_Loss 0.908 | V_Acc  0.25 | 0.631
# Epoch: 381 | T_Loss 0.605 | T_Acc 0.667 | V_Loss 0.886 | V_Acc   0.5 | 0.664
# Epoch: 380 | T_Loss 0.611 | T_Acc 0.639 | V_Loss 0.863 | V_Acc   0.5 | 0.644
# Epoch: 379 | T_Loss 0.613 | T_Acc 0.639 | V_Loss 0.836 | V_Acc   0.5 | 0.631
# Epoch: 378 | T_Loss 0.616 | T_Acc 0.639 | V_Loss 0.809 | V_Acc   0.5 | 0.634
# Epoch: 377 | T_Loss  0.62 | T_Acc 0.639 | V_Loss 0.786 | V_Acc   0.5 | 0.641
# Epoch: 376 | T_Loss 0.626 | T_Acc 0.639 | V_Loss 0.766 | V_Acc   0.5 | 0.625
# Epoch: 375 | T_Loss 0.628 | T_Acc 0.639 | V_Loss 0.751 | V_Acc   0.5 | 0.627
# Epoch: 374 | T_Loss 0.631 | T_Acc 0.639 | V_Loss 0.741 | V_Acc   0.5 | 0.638
# Epoch: 373 | T_Loss 0.632 | T_Acc 0.639 | V_Loss 0.733 | V_Acc   0.5 | 0.611
# Epoch: 372 | T_Loss 0.633 | T_Acc 0.639 | V_Loss 0.728 | V_Acc   0.5 | 0.649
# Epoch: 371 | T_Loss 0.639 | T_Acc 0.639 | V_Loss 0.725 | V_Acc   0.5 |  0.63
# Epoch: 370 | T_Loss 0.641 | T_Acc 0.639 | V_Loss 0.722 | V_Acc   0.5 | 0.609
# Epoch: 369 | T_Loss 0.647 | T_Acc 0.639 | V_Loss  0.72 | V_Acc   0.5 | 0.641
# Epoch: 368 | T_Loss 0.652 | T_Acc 0.611 | V_Loss 0.718 | V_Acc   0.5 | 0.616
# Epoch: 367 | T_Loss 0.655 | T_Acc 0.611 | V_Loss 0.717 | V_Acc   0.5 | 0.653
# Epoch: 366 | T_Loss 0.658 | T_Acc 0.611 | V_Loss 0.715 | V_Acc   0.5 | 0.631
# Epoch: 365 | T_Loss 0.658 | T_Acc 0.611 | V_Loss 0.714 | V_Acc   0.5 | 0.604
# Epoch: 364 | T_Loss 0.663 | T_Acc 0.611 | V_Loss 0.713 | V_Acc   0.5 | 0.647
# Epoch: 363 | T_Loss 0.662 | T_Acc 0.611 | V_Loss 0.711 | V_Acc   0.5 | 0.614
# Epoch: 362 | T_Loss 0.665 | T_Acc 0.611 | V_Loss  0.71 | V_Acc   0.5 | 0.643
# Epoch: 361 | T_Loss 0.665 | T_Acc 0.611 | V_Loss 0.709 | V_Acc   0.5 | 0.642
# Epoch: 360 | T_Loss 0.666 | T_Acc 0.611 | V_Loss 0.707 | V_Acc   0.5 | 0.604
# Epoch: 359 | T_Loss 0.666 | T_Acc 0.611 | V_Loss 0.705 | V_Acc   0.5 | 0.605
# Epoch: 358 | T_Loss 0.669 | T_Acc 0.611 | V_Loss 0.703 | V_Acc   0.5 | 0.638
# Epoch: 357 | T_Loss 0.676 | T_Acc 0.611 | V_Loss 0.701 | V_Acc   0.5 | 0.627
# Epoch: 356 | T_Loss 0.682 | T_Acc 0.583 | V_Loss 0.699 | V_Acc   0.5 |  0.61
# Epoch: 355 | T_Loss 0.686 | T_Acc 0.583 | V_Loss 0.698 | V_Acc   0.5 | 0.632
# Epoch: 354 | T_Loss 0.689 | T_Acc 0.583 | V_Loss 0.698 | V_Acc   0.5 | 0.634
# Epoch: 353 | T_Loss 0.723 | T_Acc 0.444 | V_Loss 0.708 | V_Acc   0.5 | 0.596
# Epoch: 352 | T_Loss 0.701 | T_Acc 0.556 | V_Loss 0.625 | V_Acc  0.75 | 0.619
# Epoch: 351 | T_Loss 0.621 | T_Acc 0.639 | V_Loss 0.906 | V_Acc   0.5 | 0.629
# Epoch: 350 | T_Loss 0.621 | T_Acc 0.639 | V_Loss 0.903 | V_Acc   0.5 | 0.628
# Epoch: 349 | T_Loss 0.624 | T_Acc 0.639 | V_Loss 0.903 | V_Acc   0.5 | 0.593
# Epoch: 348 | T_Loss 0.628 | T_Acc 0.639 | V_Loss 0.901 | V_Acc   0.5 | 0.617
# Epoch: 347 | T_Loss 0.628 | T_Acc 0.639 | V_Loss 0.899 | V_Acc   0.5 | 0.623
# Epoch: 346 | T_Loss  0.63 | T_Acc 0.639 | V_Loss 0.896 | V_Acc   0.5 |  0.59
# Epoch: 345 | T_Loss 0.631 | T_Acc 0.611 | V_Loss 0.892 | V_Acc   0.5 | 0.591
# Epoch: 344 | T_Loss 0.634 | T_Acc 0.611 | V_Loss  0.89 | V_Acc   0.5 | 0.587
# Epoch: 343 | T_Loss 0.635 | T_Acc 0.611 | V_Loss 0.887 | V_Acc   0.5 | 0.587
# Epoch: 342 | T_Loss 0.637 | T_Acc 0.611 | V_Loss 0.884 | V_Acc   0.5 | 0.616
# Epoch: 341 | T_Loss  0.64 | T_Acc 0.611 | V_Loss 0.881 | V_Acc   0.5 | 0.617
# Epoch: 340 | T_Loss 0.642 | T_Acc 0.611 | V_Loss 0.879 | V_Acc   0.5 | 0.613
# Epoch: 339 | T_Loss 0.644 | T_Acc 0.611 | V_Loss 0.877 | V_Acc   0.5 | 0.609
# Epoch: 338 | T_Loss 0.648 | T_Acc 0.611 | V_Loss 0.876 | V_Acc   0.5 | 0.611
# Epoch: 337 | T_Loss 0.649 | T_Acc 0.611 | V_Loss 0.873 | V_Acc   0.5 | 0.609
# Epoch: 336 | T_Loss 0.651 | T_Acc 0.611 | V_Loss 0.872 | V_Acc   0.5 | 0.608
# Epoch: 335 | T_Loss 0.652 | T_Acc 0.611 | V_Loss 0.871 | V_Acc   0.5 | 0.605
# Epoch: 334 | T_Loss 0.654 | T_Acc 0.611 | V_Loss 0.871 | V_Acc   0.5 | 0.605
# Epoch: 333 | T_Loss 0.656 | T_Acc 0.611 | V_Loss  0.87 | V_Acc   0.5 | 0.604
# Epoch: 332 | T_Loss 0.659 | T_Acc 0.583 | V_Loss  0.87 | V_Acc   0.5 | 0.602
# Epoch: 331 | T_Loss 0.661 | T_Acc 0.583 | V_Loss  0.87 | V_Acc   0.5 | 0.603
# Epoch: 330 | T_Loss 0.664 | T_Acc 0.583 | V_Loss  0.87 | V_Acc   0.5 | 0.593
# Epoch: 329 | T_Loss 0.661 | T_Acc 0.583 | V_Loss 0.869 | V_Acc   0.5 | 0.598
# Epoch: 328 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.868 | V_Acc   0.5 | 0.597
# Epoch: 327 | T_Loss 0.648 | T_Acc 0.583 | V_Loss 0.866 | V_Acc   0.5 | 0.563
# Epoch: 326 | T_Loss 0.658 | T_Acc 0.583 | V_Loss 1.011 | V_Acc   0.5 | 0.594
# Epoch: 325 | T_Loss 0.642 | T_Acc 0.583 | V_Loss 0.942 | V_Acc   0.5 | 0.592
# Epoch: 324 | T_Loss 0.657 | T_Acc 0.583 | V_Loss 0.982 | V_Acc   0.5 | 0.592
# Epoch: 323 | T_Loss 0.659 | T_Acc 0.583 | V_Loss 0.983 | V_Acc   0.5 | 0.591
# Epoch: 322 | T_Loss 0.661 | T_Acc 0.583 | V_Loss 0.912 | V_Acc   0.5 | 0.591
# Epoch: 321 | T_Loss 0.662 | T_Acc 0.583 | V_Loss 0.859 | V_Acc   0.5 | 0.587
# Epoch: 320 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.847 | V_Acc   0.5 | 0.586
# Epoch: 319 | T_Loss 0.666 | T_Acc 0.583 | V_Loss 0.846 | V_Acc   0.5 | 0.543
# Epoch: 318 | T_Loss 0.669 | T_Acc 0.583 | V_Loss 0.845 | V_Acc   0.5 | 0.584
# Epoch: 317 | T_Loss 0.661 | T_Acc 0.583 | V_Loss 0.844 | V_Acc   0.5 | 0.556
# Epoch: 316 | T_Loss 0.672 | T_Acc 0.583 | V_Loss 0.964 | V_Acc   0.5 |  0.58
# Epoch: 315 | T_Loss 0.662 | T_Acc 0.583 | V_Loss 0.908 | V_Acc   0.5 | 0.579
# Epoch: 314 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.965 | V_Acc   0.5 | 0.578
# Epoch: 313 | T_Loss 0.665 | T_Acc 0.583 | V_Loss 0.903 | V_Acc   0.5 | 0.578
# Epoch: 312 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.847 | V_Acc   0.5 | 0.535
# Epoch: 311 | T_Loss 0.674 | T_Acc 0.583 | V_Loss  0.85 | V_Acc   0.5 | 0.574
# Epoch: 310 | T_Loss  0.66 | T_Acc 0.583 | V_Loss  0.85 | V_Acc   0.5 | 0.571
# Epoch: 309 | T_Loss 0.666 | T_Acc 0.583 | V_Loss 0.924 | V_Acc   0.5 | 0.537
# Epoch: 308 | T_Loss 0.662 | T_Acc 0.583 | V_Loss  0.99 | V_Acc   0.5 |  0.57
# Epoch: 307 | T_Loss 0.662 | T_Acc 0.583 | V_Loss  0.97 | V_Acc   0.5 | 0.565
# Epoch: 306 | T_Loss 0.661 | T_Acc 0.583 | V_Loss 0.868 | V_Acc   0.5 | 0.568
# Epoch: 305 | T_Loss 0.665 | T_Acc 0.583 | V_Loss 0.851 | V_Acc   0.5 | 0.526
# Epoch: 304 | T_Loss 0.674 | T_Acc 0.583 | V_Loss 0.852 | V_Acc   0.5 | 0.526
# Epoch: 303 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.854 | V_Acc   0.5 | 0.531
# Epoch: 302 | T_Loss 0.677 | T_Acc 0.583 | V_Loss 0.856 | V_Acc   0.5 | 0.526
# Epoch: 301 | T_Loss 0.661 | T_Acc 0.583 | V_Loss 0.854 | V_Acc   0.5 | 0.532
# Epoch: 300 | T_Loss  0.65 | T_Acc 0.611 | V_Loss 0.848 | V_Acc   0.5 | 0.523
# Epoch: 299 | T_Loss  0.65 | T_Acc 0.611 | V_Loss 0.841 | V_Acc   0.5 | 0.544
# Epoch: 298 | T_Loss 0.642 | T_Acc 0.611 | V_Loss  0.84 | V_Acc   0.5 | 0.518
# Epoch: 297 | T_Loss 0.638 | T_Acc 0.611 | V_Loss 0.949 | V_Acc   0.5 | 0.515
# Epoch: 296 | T_Loss 0.639 | T_Acc 0.611 | V_Loss 0.917 | V_Acc   0.5 | 0.524
# Epoch: 295 | T_Loss 0.643 | T_Acc 0.611 | V_Loss  0.91 | V_Acc   0.5 | 0.522
# Epoch: 294 | T_Loss 0.645 | T_Acc 0.611 | V_Loss  0.88 | V_Acc   0.5 |  0.51
# Epoch: 293 | T_Loss 0.649 | T_Acc 0.611 | V_Loss 0.862 | V_Acc   0.5 | 0.512
# Epoch: 292 | T_Loss 0.653 | T_Acc 0.611 | V_Loss 0.839 | V_Acc   0.5 | 0.507
# Epoch: 291 | T_Loss 0.653 | T_Acc 0.611 | V_Loss 0.819 | V_Acc   0.5 | 0.511
# Epoch: 290 | T_Loss 0.655 | T_Acc 0.611 | V_Loss 0.799 | V_Acc   0.5 | 0.513
# Epoch: 289 | T_Loss 0.658 | T_Acc 0.611 | V_Loss 0.786 | V_Acc   0.5 |  0.51
# Epoch: 288 | T_Loss 0.662 | T_Acc 0.611 | V_Loss 0.776 | V_Acc   0.5 | 0.506
# Epoch: 287 | T_Loss 0.662 | T_Acc 0.611 | V_Loss 0.769 | V_Acc   0.5 | 0.517
# Epoch: 286 | T_Loss 0.661 | T_Acc 0.611 | V_Loss 0.764 | V_Acc   0.5 | 0.513
# Epoch: 285 | T_Loss 0.665 | T_Acc 0.611 | V_Loss 0.758 | V_Acc   0.5 | 0.518
# Epoch: 284 | T_Loss 0.661 | T_Acc 0.611 | V_Loss 0.753 | V_Acc   0.5 | 0.497
# Epoch: 283 | T_Loss 0.662 | T_Acc 0.611 | V_Loss 0.748 | V_Acc   0.5 | 0.502
# Epoch: 282 | T_Loss 0.664 | T_Acc 0.611 | V_Loss 0.743 | V_Acc   0.5 | 0.519
# Epoch: 281 | T_Loss 0.667 | T_Acc 0.611 | V_Loss  0.74 | V_Acc   0.5 |   0.5
# Epoch: 280 | T_Loss 0.666 | T_Acc 0.611 | V_Loss 0.738 | V_Acc   0.5 | 0.517
# Epoch: 279 | T_Loss 0.668 | T_Acc 0.611 | V_Loss 0.737 | V_Acc   0.5 | 0.517
# Epoch: 278 | T_Loss 0.672 | T_Acc 0.611 | V_Loss 0.735 | V_Acc   0.5 | 0.495
# Epoch: 277 | T_Loss 0.667 | T_Acc 0.611 | V_Loss 0.733 | V_Acc   0.5 | 0.514
# Epoch: 276 | T_Loss 0.668 | T_Acc 0.611 | V_Loss 0.731 | V_Acc   0.5 | 0.491
# Epoch: 275 | T_Loss 0.669 | T_Acc 0.611 | V_Loss  0.73 | V_Acc   0.5 | 0.503
# Epoch: 274 | T_Loss 0.668 | T_Acc 0.611 | V_Loss 0.729 | V_Acc   0.5 | 0.486
# Epoch: 273 | T_Loss 0.667 | T_Acc 0.611 | V_Loss 0.728 | V_Acc   0.5 | 0.485
# Epoch: 272 | T_Loss 0.669 | T_Acc 0.611 | V_Loss 0.727 | V_Acc   0.5 | 0.489
# Epoch: 271 | T_Loss 0.669 | T_Acc 0.611 | V_Loss 0.726 | V_Acc   0.5 | 0.484
# Epoch: 270 | T_Loss 0.669 | T_Acc 0.611 | V_Loss 0.726 | V_Acc   0.5 |  0.48
# Epoch: 269 | T_Loss 0.669 | T_Acc 0.611 | V_Loss 0.725 | V_Acc   0.5 | 0.478
# Epoch: 268 | T_Loss 0.669 | T_Acc 0.611 | V_Loss 0.725 | V_Acc   0.5 | 0.477
# Epoch: 267 | T_Loss 0.668 | T_Acc 0.611 | V_Loss 0.724 | V_Acc   0.5 | 0.478
# Epoch: 266 | T_Loss 0.667 | T_Acc 0.611 | V_Loss 0.724 | V_Acc   0.5 | 0.477
# Epoch: 265 | T_Loss  0.67 | T_Acc 0.611 | V_Loss 0.723 | V_Acc   0.5 | 0.485
# Epoch: 264 | T_Loss  0.67 | T_Acc 0.611 | V_Loss 0.723 | V_Acc   0.5 | 0.473
# Epoch: 263 | T_Loss  0.67 | T_Acc 0.611 | V_Loss 0.722 | V_Acc   0.5 | 0.472
# Epoch: 262 | T_Loss 0.672 | T_Acc 0.611 | V_Loss 0.722 | V_Acc   0.5 |  0.47
# Epoch: 261 | T_Loss 0.673 | T_Acc 0.611 | V_Loss 0.722 | V_Acc   0.5 | 0.474
# Epoch: 260 | T_Loss  0.67 | T_Acc 0.611 | V_Loss 0.722 | V_Acc   0.5 | 0.484
# Epoch: 259 | T_Loss 0.674 | T_Acc 0.611 | V_Loss 0.721 | V_Acc   0.5 | 1.975
# Epoch: 258 | T_Loss 0.673 | T_Acc 0.611 | V_Loss 0.721 | V_Acc   0.5 | 0.471
# Epoch: 257 | T_Loss 0.671 | T_Acc 0.611 | V_Loss  0.72 | V_Acc   0.5 | 0.469
# Epoch: 256 | T_Loss 0.674 | T_Acc 0.611 | V_Loss  0.72 | V_Acc   0.5 | 0.488
# Epoch: 255 | T_Loss 0.673 | T_Acc 0.611 | V_Loss  0.72 | V_Acc   0.5 | 0.464
# Epoch: 254 | T_Loss 0.673 | T_Acc 0.611 | V_Loss 0.719 | V_Acc   0.5 | 0.472
# Epoch: 253 | T_Loss 0.676 | T_Acc 0.611 | V_Loss 0.719 | V_Acc   0.5 | 0.461
# Epoch: 252 | T_Loss 0.674 | T_Acc 0.583 | V_Loss 0.719 | V_Acc   0.5 | 0.493
# Epoch: 251 | T_Loss 0.674 | T_Acc 0.611 | V_Loss 0.719 | V_Acc   0.5 | 0.493
# Epoch: 250 | T_Loss 0.675 | T_Acc 0.583 | V_Loss  0.72 | V_Acc   0.5 | 0.465
# Epoch: 249 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.719 | V_Acc   0.5 | 0.464
# Epoch: 248 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.719 | V_Acc   0.5 | 0.485
# Epoch: 247 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.719 | V_Acc   0.5 | 0.452
# Epoch: 246 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.719 | V_Acc   0.5 | 0.471
# Epoch: 245 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.718 | V_Acc   0.5 | 0.473
# Epoch: 244 | T_Loss 0.678 | T_Acc 0.583 | V_Loss 0.718 | V_Acc   0.5 | 0.455
# Epoch: 243 | T_Loss 0.678 | T_Acc 0.583 | V_Loss 0.717 | V_Acc   0.5 | 0.462
# Epoch: 242 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.717 | V_Acc   0.5 | 0.449
# Epoch: 241 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.717 | V_Acc   0.5 | 0.449
# Epoch: 240 | T_Loss  0.68 | T_Acc 0.583 | V_Loss 0.717 | V_Acc   0.5 | 0.452
# Epoch: 239 | T_Loss  0.68 | T_Acc 0.583 | V_Loss 0.717 | V_Acc   0.5 | 0.458
# Epoch: 238 | T_Loss 0.679 | T_Acc 0.583 | V_Loss 0.717 | V_Acc   0.5 | 0.456
# Epoch: 237 | T_Loss 0.679 | T_Acc 0.583 | V_Loss 0.718 | V_Acc   0.5 | 0.449
# Epoch: 236 | T_Loss 0.679 | T_Acc 0.583 | V_Loss 0.718 | V_Acc   0.5 |  0.44
# Epoch: 235 | T_Loss 0.681 | T_Acc 0.583 | V_Loss 0.718 | V_Acc   0.5 | 0.444
# Epoch: 234 | T_Loss  0.68 | T_Acc 0.583 | V_Loss 0.718 | V_Acc   0.5 | 0.439
# Epoch: 233 | T_Loss  0.68 | T_Acc 0.583 | V_Loss 0.717 | V_Acc   0.5 |  0.45
# Epoch: 232 | T_Loss  0.68 | T_Acc 0.583 | V_Loss 0.716 | V_Acc   0.5 | 0.447
# Epoch: 231 | T_Loss  0.68 | T_Acc 0.583 | V_Loss 0.715 | V_Acc   0.5 | 0.447
# Epoch: 230 | T_Loss 0.681 | T_Acc 0.583 | V_Loss 0.713 | V_Acc   0.5 | 0.444
# Epoch: 229 | T_Loss 0.684 | T_Acc 0.583 | V_Loss 0.711 | V_Acc   0.5 | 0.435
# Epoch: 228 | T_Loss 0.683 | T_Acc 0.583 | V_Loss 0.709 | V_Acc   0.5 | 0.444
# Epoch: 227 | T_Loss 0.686 | T_Acc 0.583 | V_Loss 0.706 | V_Acc   0.5 | 0.426
# Epoch: 226 | T_Loss 0.687 | T_Acc 0.583 | V_Loss 0.704 | V_Acc   0.5 | 0.433
# Epoch: 225 | T_Loss 0.689 | T_Acc 0.583 | V_Loss 0.702 | V_Acc   0.5 | 0.424
# Epoch: 224 | T_Loss 0.693 | T_Acc 0.583 | V_Loss   0.7 | V_Acc   0.5 | 0.422
# Epoch: 223 | T_Loss 0.694 | T_Acc 0.556 | V_Loss 0.698 | V_Acc   0.5 | 0.435
# Epoch: 222 | T_Loss 0.683 | T_Acc 0.583 | V_Loss 0.698 | V_Acc   0.5 | 0.421
# Epoch: 221 | T_Loss 0.672 | T_Acc 0.583 | V_Loss 0.748 | V_Acc   0.5 | 0.427
# Epoch: 220 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.746 | V_Acc   0.5 | 0.422
# Epoch: 219 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.743 | V_Acc   0.5 | 0.422
# Epoch: 218 | T_Loss 0.678 | T_Acc 0.583 | V_Loss 0.741 | V_Acc   0.5 | 0.427
# Epoch: 217 | T_Loss 0.683 | T_Acc 0.583 | V_Loss 0.739 | V_Acc   0.5 | 0.423
# Epoch: 216 | T_Loss 0.674 | T_Acc 0.583 | V_Loss 0.736 | V_Acc   0.5 | 0.412
# Epoch: 215 | T_Loss 0.674 | T_Acc 0.583 | V_Loss 0.782 | V_Acc   0.5 | 0.418
# Epoch: 214 | T_Loss 0.675 | T_Acc 0.611 | V_Loss 0.767 | V_Acc   0.5 | 0.422
# Epoch: 213 | T_Loss 0.672 | T_Acc 0.583 | V_Loss 0.756 | V_Acc   0.5 | 0.422
# Epoch: 212 | T_Loss 0.691 | T_Acc 0.556 | V_Loss  0.77 | V_Acc  0.25 | 0.415
# Epoch: 211 | T_Loss 0.681 | T_Acc 0.583 | V_Loss 0.727 | V_Acc   0.5 | 0.423
# Epoch: 210 | T_Loss 0.684 | T_Acc 0.556 | V_Loss  0.73 | V_Acc   0.5 | 0.421
# Epoch: 209 | T_Loss 0.693 | T_Acc 0.528 | V_Loss 0.734 | V_Acc   0.5 | 0.408
# Epoch: 208 | T_Loss 0.679 | T_Acc 0.611 | V_Loss 0.742 | V_Acc  0.25 | 0.412
# Epoch: 207 | T_Loss 0.691 | T_Acc 0.583 | V_Loss 0.704 | V_Acc   0.5 | 0.417
# Epoch: 206 | T_Loss 0.682 | T_Acc 0.528 | V_Loss 0.706 | V_Acc   0.5 | 0.403
# Epoch: 205 | T_Loss 0.687 | T_Acc 0.528 | V_Loss 0.706 | V_Acc   0.5 |   0.4
# Epoch: 204 | T_Loss 0.685 | T_Acc 0.528 | V_Loss 0.706 | V_Acc   0.5 | 0.413
# Epoch: 203 | T_Loss  0.67 | T_Acc 0.611 | V_Loss 0.706 | V_Acc   0.5 |   0.4
# Epoch: 202 | T_Loss 0.668 | T_Acc 0.667 | V_Loss 0.706 | V_Acc   0.5 | 0.397
# Epoch: 201 | T_Loss 0.684 | T_Acc 0.639 | V_Loss 0.705 | V_Acc   0.5 |  0.41
# Epoch: 200 | T_Loss 0.672 | T_Acc 0.556 | V_Loss 0.694 | V_Acc   0.5 | 0.409
# Epoch: 199 | T_Loss 0.681 | T_Acc 0.528 | V_Loss 0.707 | V_Acc   0.5 | 0.408
# Epoch: 198 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.709 | V_Acc   0.5 | 0.407
# Epoch: 197 | T_Loss 0.667 | T_Acc 0.583 | V_Loss 0.709 | V_Acc   0.5 | 0.405
# Epoch: 196 | T_Loss  0.67 | T_Acc 0.583 | V_Loss  0.71 | V_Acc   0.5 | 0.403
# Epoch: 195 | T_Loss 0.672 | T_Acc 0.583 | V_Loss  0.71 | V_Acc   0.5 | 0.402
# Epoch: 194 | T_Loss 0.669 | T_Acc 0.583 | V_Loss  0.71 | V_Acc   0.5 | 0.401
# Epoch: 193 | T_Loss 0.672 | T_Acc 0.583 | V_Loss  0.71 | V_Acc   0.5 | 0.399
# Epoch: 192 | T_Loss 0.677 | T_Acc 0.583 | V_Loss  0.71 | V_Acc   0.5 | 0.399
# Epoch: 191 | T_Loss 0.673 | T_Acc 0.583 | V_Loss  0.71 | V_Acc   0.5 | 0.398
# Epoch: 190 | T_Loss 0.675 | T_Acc 0.583 | V_Loss  0.71 | V_Acc   0.5 | 0.396
# Epoch: 189 | T_Loss 0.677 | T_Acc 0.583 | V_Loss  0.71 | V_Acc   0.5 | 0.395
# Epoch: 188 | T_Loss 0.674 | T_Acc 0.583 | V_Loss 0.711 | V_Acc   0.5 | 0.394
# Epoch: 187 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.711 | V_Acc   0.5 | 0.379
# Epoch: 186 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.711 | V_Acc   0.5 | 0.379
# Epoch: 185 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.711 | V_Acc   0.5 |  0.39
# Epoch: 184 | T_Loss 0.674 | T_Acc 0.583 | V_Loss 0.711 | V_Acc   0.5 | 0.381
# Epoch: 183 | T_Loss 0.673 | T_Acc 0.583 | V_Loss 0.711 | V_Acc   0.5 | 0.387
# Epoch: 182 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.712 | V_Acc   0.5 | 0.383
# Epoch: 181 | T_Loss 0.677 | T_Acc 0.583 | V_Loss 0.712 | V_Acc   0.5 | 0.375
# Epoch: 180 | T_Loss 0.673 | T_Acc 0.583 | V_Loss 0.713 | V_Acc   0.5 | 0.376
# Epoch: 179 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.713 | V_Acc   0.5 | 0.381
# Epoch: 178 | T_Loss 0.678 | T_Acc 0.583 | V_Loss 0.715 | V_Acc   0.5 | 0.378
# Epoch: 177 | T_Loss 0.678 | T_Acc 0.583 | V_Loss 0.716 | V_Acc   0.5 | 0.379
# Epoch: 176 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.717 | V_Acc   0.5 | 0.375
# Epoch: 175 | T_Loss  0.68 | T_Acc 0.556 | V_Loss 0.717 | V_Acc   0.5 | 0.375
# Epoch: 174 | T_Loss 0.675 | T_Acc 0.556 | V_Loss 0.718 | V_Acc   0.5 | 0.372
# Epoch: 173 | T_Loss 0.675 | T_Acc 0.583 | V_Loss  0.72 | V_Acc   0.5 | 0.374
# Epoch: 172 | T_Loss 0.673 | T_Acc 0.611 | V_Loss  0.72 | V_Acc   0.5 | 0.365
# Epoch: 171 | T_Loss 0.666 | T_Acc 0.611 | V_Loss  0.72 | V_Acc   0.5 | 0.383
# Epoch: 170 | T_Loss 0.672 | T_Acc 0.611 | V_Loss 0.718 | V_Acc   0.5 | 0.368
# Epoch: 169 | T_Loss 0.672 | T_Acc 0.611 | V_Loss 0.716 | V_Acc   0.5 | 0.382
# Epoch: 168 | T_Loss  0.67 | T_Acc 0.611 | V_Loss 0.714 | V_Acc   0.5 |  0.36
# Epoch: 167 | T_Loss 0.671 | T_Acc 0.611 | V_Loss 0.711 | V_Acc   0.5 | 0.367
# Epoch: 166 | T_Loss 0.682 | T_Acc 0.583 | V_Loss 0.709 | V_Acc   0.5 | 0.354
# Epoch: 165 | T_Loss  0.67 | T_Acc 0.611 | V_Loss 0.708 | V_Acc   0.5 | 0.376
# Epoch: 164 | T_Loss 0.682 | T_Acc 0.528 | V_Loss 0.709 | V_Acc   0.5 | 0.355
# Epoch: 163 | T_Loss 0.686 | T_Acc 0.528 | V_Loss 0.711 | V_Acc   0.5 | 0.352
# Epoch: 162 | T_Loss 0.685 | T_Acc 0.528 | V_Loss 0.714 | V_Acc   0.5 | 0.346
# Epoch: 161 | T_Loss 0.689 | T_Acc 0.556 | V_Loss 0.718 | V_Acc   0.5 | 0.345
# Epoch: 160 | T_Loss 0.686 | T_Acc 0.556 | V_Loss 0.723 | V_Acc   0.5 | 0.356
# Epoch: 159 | T_Loss 0.677 | T_Acc 0.583 | V_Loss  0.79 | V_Acc  0.25 | 0.341
# Epoch: 158 | T_Loss  0.68 | T_Acc 0.556 | V_Loss 0.801 | V_Acc  0.25 | 0.344
# Epoch: 157 | T_Loss 0.684 | T_Acc 0.556 | V_Loss 0.816 | V_Acc  0.25 | 0.338
# Epoch: 156 | T_Loss 0.688 | T_Acc 0.556 | V_Loss 0.839 | V_Acc  0.25 | 0.342
# Epoch: 155 | T_Loss   0.7 | T_Acc 0.583 | V_Loss 0.872 | V_Acc  0.25 | 0.352
# Epoch: 154 | T_Loss 0.738 | T_Acc 0.528 | V_Loss 0.814 | V_Acc   0.5 | 0.341
# Epoch: 153 | T_Loss 0.787 | T_Acc 0.528 | V_Loss 0.856 | V_Acc   0.5 | 0.348
# Epoch: 152 | T_Loss 0.844 | T_Acc   0.5 | V_Loss 0.914 | V_Acc   0.5 | 0.339
# Epoch: 151 | T_Loss  0.88 | T_Acc   0.5 | V_Loss 0.986 | V_Acc   0.5 | 0.338
# Epoch: 150 | T_Loss 0.896 | T_Acc   0.5 | V_Loss 1.065 | V_Acc   0.5 | 0.335
# Epoch: 149 | T_Loss 0.876 | T_Acc   0.5 | V_Loss 1.224 | V_Acc   0.5 | 0.331
# Epoch: 148 | T_Loss 0.553 | T_Acc 0.694 | V_Loss 1.318 | V_Acc  0.25 | 0.328
# Epoch: 147 | T_Loss  0.57 | T_Acc 0.694 | V_Loss 1.309 | V_Acc  0.25 | 0.325
# Epoch: 146 | T_Loss 0.576 | T_Acc 0.667 | V_Loss 1.301 | V_Acc  0.25 | 0.328
# Epoch: 145 | T_Loss 0.574 | T_Acc 0.694 | V_Loss 1.292 | V_Acc  0.25 | 0.324
# Epoch: 144 | T_Loss 0.579 | T_Acc 0.639 | V_Loss 1.283 | V_Acc  0.25 | 0.329
# Epoch: 143 | T_Loss 0.578 | T_Acc 0.667 | V_Loss 1.274 | V_Acc  0.25 | 0.322
# Epoch: 142 | T_Loss 0.577 | T_Acc 0.667 | V_Loss 1.264 | V_Acc  0.25 | 0.322
# Epoch: 141 | T_Loss 0.577 | T_Acc 0.583 | V_Loss 1.253 | V_Acc  0.25 | 0.326
# Epoch: 140 | T_Loss 0.579 | T_Acc 0.583 | V_Loss 1.242 | V_Acc  0.25 |  0.32
# Epoch: 139 | T_Loss  0.58 | T_Acc 0.583 | V_Loss 1.231 | V_Acc  0.25 | 0.319
# Epoch: 138 | T_Loss 0.581 | T_Acc 0.583 | V_Loss  1.22 | V_Acc  0.25 | 0.318
# Epoch: 137 | T_Loss 0.582 | T_Acc 0.583 | V_Loss 1.208 | V_Acc   0.5 | 0.314
# Epoch: 136 | T_Loss 0.584 | T_Acc 0.611 | V_Loss 1.196 | V_Acc   0.5 | 0.317
# Epoch: 135 | T_Loss 0.583 | T_Acc 0.583 | V_Loss 1.183 | V_Acc   0.5 | 0.315
# Epoch: 134 | T_Loss 0.585 | T_Acc 0.583 | V_Loss  1.17 | V_Acc   0.5 | 0.317
# Epoch: 133 | T_Loss 0.587 | T_Acc 0.583 | V_Loss 1.156 | V_Acc   0.5 | 0.306
# Epoch: 132 | T_Loss 0.587 | T_Acc 0.583 | V_Loss 1.143 | V_Acc   0.5 | 0.317
# Epoch: 131 | T_Loss 0.588 | T_Acc 0.583 | V_Loss 1.129 | V_Acc   0.5 | 0.309
# Epoch: 130 | T_Loss 0.594 | T_Acc 0.583 | V_Loss 1.115 | V_Acc   0.5 | 0.304
# Epoch: 129 | T_Loss 0.596 | T_Acc 0.583 | V_Loss 1.102 | V_Acc   0.5 | 0.307
# Epoch: 128 | T_Loss 0.598 | T_Acc 0.583 | V_Loss 1.088 | V_Acc   0.5 | 0.302
# Epoch: 127 | T_Loss 0.607 | T_Acc 0.583 | V_Loss 1.076 | V_Acc   0.5 | 0.305
# Epoch: 126 | T_Loss 0.625 | T_Acc 0.583 | V_Loss 1.064 | V_Acc   0.5 | 0.299
# Epoch: 125 | T_Loss 0.635 | T_Acc 0.583 | V_Loss 1.053 | V_Acc   0.5 | 0.301
# Epoch: 124 | T_Loss 0.646 | T_Acc 0.583 | V_Loss 1.037 | V_Acc   0.5 |   0.3
# Epoch: 123 | T_Loss 0.653 | T_Acc 0.583 | V_Loss 0.938 | V_Acc   0.5 |   0.3
# Epoch: 122 | T_Loss 0.656 | T_Acc 0.583 | V_Loss  0.92 | V_Acc   0.5 | 0.294
# Epoch: 121 | T_Loss 0.659 | T_Acc 0.583 | V_Loss 0.918 | V_Acc   0.5 | 0.297
# Epoch: 120 | T_Loss 0.659 | T_Acc 0.583 | V_Loss 0.918 | V_Acc   0.5 | 0.299
# Epoch: 119 | T_Loss  0.66 | T_Acc 0.583 | V_Loss 0.918 | V_Acc   0.5 | 0.295
# Epoch: 118 | T_Loss  0.66 | T_Acc 0.583 | V_Loss 0.919 | V_Acc   0.5 | 0.289
# Epoch: 117 | T_Loss  0.66 | T_Acc 0.583 | V_Loss 0.921 | V_Acc   0.5 | 0.287
# Epoch: 116 | T_Loss 0.661 | T_Acc 0.583 | V_Loss 0.922 | V_Acc   0.5 | 0.289
# Epoch: 115 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.923 | V_Acc   0.5 |  0.29
# Epoch: 114 | T_Loss 0.662 | T_Acc 0.583 | V_Loss 0.924 | V_Acc   0.5 |  0.29
# Epoch: 113 | T_Loss  0.66 | T_Acc 0.583 | V_Loss 0.924 | V_Acc   0.5 | 0.287
# Epoch: 112 | T_Loss 0.662 | T_Acc 0.583 | V_Loss 0.925 | V_Acc   0.5 | 0.278
# Epoch: 111 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.925 | V_Acc   0.5 | 0.279
# Epoch: 110 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.926 | V_Acc   0.5 | 0.288
# Epoch: 109 | T_Loss 0.662 | T_Acc 0.583 | V_Loss 0.927 | V_Acc   0.5 | 0.282
# Epoch: 108 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.928 | V_Acc   0.5 | 0.294
# Epoch: 107 | T_Loss 0.662 | T_Acc 0.583 | V_Loss 0.929 | V_Acc   0.5 | 0.294
# Epoch: 106 | T_Loss 0.662 | T_Acc 0.583 | V_Loss 0.931 | V_Acc   0.5 | 0.283
# Epoch: 105 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.932 | V_Acc   0.5 | 0.291
# Epoch: 104 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.932 | V_Acc   0.5 |  0.27
# Epoch: 103 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.933 | V_Acc   0.5 | 0.268
# Epoch: 102 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.934 | V_Acc   0.5 | 0.267
# Epoch: 101 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.936 | V_Acc   0.5 | 0.268
# Epoch: 100 | T_Loss 0.665 | T_Acc 0.583 | V_Loss 0.937 | V_Acc   0.5 | 0.272
# Epoch:  99 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.938 | V_Acc   0.5 | 0.266
# Epoch:  98 | T_Loss 0.665 | T_Acc 0.583 | V_Loss 0.939 | V_Acc   0.5 | 0.271
# Epoch:  97 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.941 | V_Acc   0.5 | 0.267
# Epoch:  96 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.942 | V_Acc   0.5 | 0.278
# Epoch:  95 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.942 | V_Acc   0.5 | 0.277
# Epoch:  94 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.943 | V_Acc   0.5 | 0.265
# Epoch:  93 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.943 | V_Acc   0.5 | 0.272
# Epoch:  92 | T_Loss 0.665 | T_Acc 0.583 | V_Loss 0.942 | V_Acc   0.5 | 0.259
# Epoch:  91 | T_Loss 0.666 | T_Acc 0.583 | V_Loss 0.941 | V_Acc   0.5 | 0.271
# Epoch:  90 | T_Loss 0.666 | T_Acc 0.583 | V_Loss 0.937 | V_Acc   0.5 |  0.27
# Epoch:  89 | T_Loss 0.665 | T_Acc 0.583 | V_Loss 0.929 | V_Acc   0.5 | 0.269
# Epoch:  88 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.914 | V_Acc   0.5 | 0.261
# Epoch:  87 | T_Loss 0.667 | T_Acc 0.583 | V_Loss 0.901 | V_Acc   0.5 | 0.252
# Epoch:  86 | T_Loss 0.667 | T_Acc 0.583 | V_Loss  0.92 | V_Acc   0.5 | 0.253
# Epoch:  85 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.954 | V_Acc   0.5 | 0.263
# Epoch:  84 | T_Loss 0.634 | T_Acc 0.583 | V_Loss 0.964 | V_Acc   0.5 | 0.246
# Epoch:  83 | T_Loss 0.644 | T_Acc 0.583 | V_Loss 1.129 | V_Acc   0.5 | 0.244
# Epoch:  82 | T_Loss 0.607 | T_Acc 0.583 | V_Loss 1.114 | V_Acc   0.5 | 0.245
# Epoch:  81 | T_Loss 0.615 | T_Acc 0.583 | V_Loss 1.111 | V_Acc   0.5 | 0.248
# Epoch:  80 | T_Loss 0.606 | T_Acc 0.583 | V_Loss 1.094 | V_Acc   0.5 |  0.25
# Epoch:  79 | T_Loss 0.612 | T_Acc 0.583 | V_Loss  1.08 | V_Acc   0.5 | 0.237
# Epoch:  78 | T_Loss 0.644 | T_Acc 0.583 | V_Loss 1.081 | V_Acc   0.5 | 0.251
# Epoch:  77 | T_Loss 0.646 | T_Acc 0.583 | V_Loss 1.047 | V_Acc   0.5 | 0.239
# Epoch:  76 | T_Loss 0.629 | T_Acc 0.583 | V_Loss 1.053 | V_Acc   0.5 | 0.232
# Epoch:  75 | T_Loss 0.633 | T_Acc 0.583 | V_Loss 1.061 | V_Acc   0.5 | 0.238
# Epoch:  74 | T_Loss 0.636 | T_Acc 0.583 | V_Loss  1.05 | V_Acc   0.5 | 0.235
# Epoch:  73 | T_Loss 0.658 | T_Acc 0.583 | V_Loss  1.05 | V_Acc   0.5 | 0.238
# Epoch:  72 | T_Loss 0.659 | T_Acc 0.583 | V_Loss 0.926 | V_Acc   0.5 | 0.227
# Epoch:  71 | T_Loss 0.661 | T_Acc 0.583 | V_Loss 0.925 | V_Acc   0.5 | 0.234
# Epoch:  70 | T_Loss 0.661 | T_Acc 0.583 | V_Loss 0.925 | V_Acc   0.5 | 0.226
# Epoch:  69 | T_Loss 0.661 | T_Acc 0.583 | V_Loss 0.926 | V_Acc   0.5 | 0.231
# Epoch:  68 | T_Loss 0.662 | T_Acc 0.583 | V_Loss 0.927 | V_Acc   0.5 | 0.222
# Epoch:  67 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.928 | V_Acc   0.5 | 0.224
# Epoch:  66 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.929 | V_Acc   0.5 | 0.222
# Epoch:  65 | T_Loss 0.664 | T_Acc 0.583 | V_Loss  0.93 | V_Acc   0.5 | 0.218
# Epoch:  64 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.931 | V_Acc   0.5 | 0.229
# Epoch:  63 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.932 | V_Acc   0.5 | 0.228
# Epoch:  62 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.933 | V_Acc   0.5 | 0.217
# Epoch:  61 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.933 | V_Acc   0.5 | 0.219
# Epoch:  60 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.934 | V_Acc   0.5 | 0.216
# Epoch:  59 | T_Loss 0.665 | T_Acc 0.583 | V_Loss 0.934 | V_Acc   0.5 |  0.21
# Epoch:  58 | T_Loss 0.665 | T_Acc 0.583 | V_Loss 0.935 | V_Acc   0.5 | 0.221
# Epoch:  57 | T_Loss 0.666 | T_Acc 0.583 | V_Loss 0.935 | V_Acc   0.5 | 0.209
# Epoch:  56 | T_Loss 0.664 | T_Acc 0.583 | V_Loss 0.935 | V_Acc   0.5 | 0.218
# Epoch:  55 | T_Loss 0.666 | T_Acc 0.583 | V_Loss 0.933 | V_Acc   0.5 |  0.21
# Epoch:  54 | T_Loss 0.667 | T_Acc 0.583 | V_Loss  0.93 | V_Acc   0.5 | 0.212
# Epoch:  53 | T_Loss 0.666 | T_Acc 0.583 | V_Loss 0.924 | V_Acc   0.5 | 0.205
# Epoch:  52 | T_Loss 0.667 | T_Acc 0.583 | V_Loss 0.915 | V_Acc   0.5 | 0.198
# Epoch:  51 | T_Loss 0.668 | T_Acc 0.583 | V_Loss 0.913 | V_Acc   0.5 |   0.2
# Epoch:  50 | T_Loss 0.666 | T_Acc 0.583 | V_Loss 0.932 | V_Acc   0.5 | 0.201
# Epoch:  49 | T_Loss 0.639 | T_Acc 0.583 | V_Loss 0.942 | V_Acc   0.5 | 0.208
# Epoch:  48 | T_Loss 0.622 | T_Acc 0.583 | V_Loss 1.084 | V_Acc   0.5 | 0.193
# Epoch:  47 | T_Loss 0.614 | T_Acc 0.583 | V_Loss 1.054 | V_Acc   0.5 | 0.206
# Epoch:  46 | T_Loss 0.611 | T_Acc 0.583 | V_Loss 1.039 | V_Acc   0.5 | 0.189
# Epoch:  45 | T_Loss 0.614 | T_Acc 0.583 | V_Loss 1.016 | V_Acc   0.5 | 0.189
# Epoch:  44 | T_Loss 0.627 | T_Acc 0.583 | V_Loss 1.005 | V_Acc   0.5 | 0.197
# Epoch:  43 | T_Loss 0.633 | T_Acc 0.583 | V_Loss 0.989 | V_Acc   0.5 | 0.189
# Epoch:  42 | T_Loss  0.65 | T_Acc 0.583 | V_Loss 0.988 | V_Acc   0.5 | 0.194
# Epoch:  41 | T_Loss 0.652 | T_Acc 0.583 | V_Loss 0.913 | V_Acc   0.5 | 0.191
# Epoch:  40 | T_Loss 0.642 | T_Acc 0.583 | V_Loss 0.892 | V_Acc   0.5 |  0.19
# Epoch:  39 | T_Loss  0.64 | T_Acc 0.583 | V_Loss 0.944 | V_Acc   0.5 | 0.189
# Epoch:  38 | T_Loss 0.649 | T_Acc 0.583 | V_Loss 0.924 | V_Acc   0.5 | 0.184
# Epoch:  37 | T_Loss 0.646 | T_Acc 0.583 | V_Loss 0.904 | V_Acc   0.5 | 0.189
# Epoch:  36 | T_Loss 0.651 | T_Acc 0.583 | V_Loss 0.882 | V_Acc   0.5 | 0.181
# Epoch:  35 | T_Loss 0.654 | T_Acc 0.583 | V_Loss 0.865 | V_Acc   0.5 | 0.184
# Epoch:  34 | T_Loss 0.658 | T_Acc 0.583 | V_Loss 0.847 | V_Acc   0.5 | 0.184
# Epoch:  33 | T_Loss  0.66 | T_Acc 0.583 | V_Loss 0.829 | V_Acc   0.5 | 0.178
# Epoch:  32 | T_Loss 0.663 | T_Acc 0.583 | V_Loss 0.812 | V_Acc   0.5 | 0.181
# Epoch:  31 | T_Loss 0.665 | T_Acc 0.583 | V_Loss 0.799 | V_Acc   0.5 | 0.176
# Epoch:  30 | T_Loss 0.668 | T_Acc 0.583 | V_Loss 0.787 | V_Acc   0.5 | 0.172
# Epoch:  29 | T_Loss 0.668 | T_Acc 0.583 | V_Loss 0.776 | V_Acc   0.5 | 0.176
# Epoch:  28 | T_Loss 0.669 | T_Acc 0.583 | V_Loss 0.767 | V_Acc   0.5 | 0.168
# Epoch:  27 | T_Loss 0.671 | T_Acc 0.583 | V_Loss  0.76 | V_Acc   0.5 | 0.174
# Epoch:  26 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.755 | V_Acc   0.5 | 0.167
# Epoch:  25 | T_Loss 0.673 | T_Acc 0.583 | V_Loss  0.75 | V_Acc   0.5 | 0.167
# Epoch:  24 | T_Loss 0.673 | T_Acc 0.583 | V_Loss 0.745 | V_Acc   0.5 | 0.168
# Epoch:  23 | T_Loss 0.675 | T_Acc 0.583 | V_Loss  0.74 | V_Acc   0.5 |  0.16
# Epoch:  22 | T_Loss 0.675 | T_Acc 0.583 | V_Loss 0.736 | V_Acc   0.5 |  0.16
# Epoch:  21 | T_Loss 0.676 | T_Acc 0.583 | V_Loss 0.733 | V_Acc   0.5 | 0.154
# Epoch:  20 | T_Loss 0.679 | T_Acc 0.583 | V_Loss  0.73 | V_Acc   0.5 | 0.161
# Epoch:  19 | T_Loss 0.678 | T_Acc 0.583 | V_Loss 0.727 | V_Acc   0.5 | 0.152
# Epoch:  18 | T_Loss 0.678 | T_Acc 0.583 | V_Loss 0.725 | V_Acc   0.5 | 0.151
# Epoch:  17 | T_Loss 0.678 | T_Acc 0.583 | V_Loss 0.724 | V_Acc   0.5 | 0.151
# Epoch:  16 | T_Loss 0.679 | T_Acc 0.583 | V_Loss 0.722 | V_Acc   0.5 | 0.149
# Epoch:  15 | T_Loss  0.68 | T_Acc 0.583 | V_Loss  0.72 | V_Acc   0.5 |  0.15
# Epoch:  14 | T_Loss 0.679 | T_Acc 0.583 | V_Loss 0.718 | V_Acc   0.5 | 0.145
# Epoch:  13 | T_Loss  0.68 | T_Acc 0.583 | V_Loss 0.716 | V_Acc   0.5 | 0.148
# Epoch:  12 | T_Loss 0.681 | T_Acc 0.583 | V_Loss 0.712 | V_Acc   0.5 | 0.143
# Epoch:  11 | T_Loss 0.684 | T_Acc 0.583 | V_Loss 0.706 | V_Acc   0.5 | 0.137
# Epoch:  10 | T_Loss 0.686 | T_Acc 0.583 | V_Loss   0.7 | V_Acc   0.5 | 0.138
# Epoch:   9 | T_Loss 0.688 | T_Acc 0.583 | V_Loss 0.697 | V_Acc   0.5 | 0.141
# Epoch:   8 | T_Loss 0.691 | T_Acc 0.583 | V_Loss 0.695 | V_Acc   0.5 |  0.14
# Epoch:   7 | T_Loss 0.692 | T_Acc 0.583 | V_Loss 0.694 | V_Acc   0.5 | 0.132
# Epoch:   6 | T_Loss 0.692 | T_Acc   0.5 | V_Loss 0.694 | V_Acc   0.5 | 0.132
# Epoch:   5 | T_Loss 0.694 | T_Acc 0.472 | V_Loss 0.693 | V_Acc   0.5 | 0.136
# Epoch:   4 | T_Loss 0.694 | T_Acc 0.417 | V_Loss 0.693 | V_Acc   0.5 | 0.128
# Epoch:   3 | T_Loss 0.695 | T_Acc 0.417 | V_Loss 0.693 | V_Acc   0.5 | 0.127
# Epoch:   2 | T_Loss 0.697 | T_Acc 0.417 | V_Loss 0.693 | V_Acc   0.5 | 0.133
# Epoch:   1 | T_Loss 0.697 | T_Acc 0.417 | V_Loss 0.693 | V_Acc   0.5 | 0.202
#
#  Training completed!

# %%
# 정확도 검증
with torch.no_grad():
    test_loss, test_acc = epoch(test_loader, mode = 'test')
    test_acc = round(test_acc, 4)
    test_loss = round(test_loss, 4)
    print('Test Acc.: {}'.format(test_acc))
    print('Test Loss: {}'.format(test_loss))
# Out:
# Test Acc.: 0.25
# Test Loss: 0.7965

# %% [markdown]
# - 1분 원본 영상으로 모델 테스트 하기

# %%
# 영상 resize 및 추출
# test_video_name = 'C_3_12_43_BU_SMC_10-14_12-17-14_CC_RGB_DF2_F2'
test_video_name = 'C_3_12_1_BU_DYA_07-31_16-15-01_CA_RGB_DF2_M1'
# test_video_path = f'/content/drive/MyDrive/Colab_Notebooks/Anomaly Detection/{test_video_name}.mp4'
test_video_path = f'/home/nkw/ihs/ihs2/zerobase_DL_project/Anomaly Detection/{test_video_name}.mp4'
cv2.destroyAllWindows()
cap = cv2.VideoCapture(test_video_path)
img_list = []

if cap.isOpened():

    while True:
        ret, img = cap.read()
        if ret:
            img = cv2.resize(img, (640, 640))
            img_list.append(img)
            # cv2_imshow(img)
            # cv2.waitKey(1)
        else:
            break

cap.release()
cv2.destroyAllWindows()

print('저장된 frame의 개수: {}'.format(len(img_list)))
# Out:
# 저장된 frame의 개수: 180

# %%
"""Yolov5 + Mediapipe Version"""

net.eval()

length = 30 # frame 상태를 표시할 길이
out_img_list = []
dataset = []
status = 'None'
pose = mp_pose.Pose(static_image_mode=True, model_complexity=1, enable_segmentation=False, min_detection_confidence=n_CONFIDENCE)
print('시퀀스 데이터 분석 중...')

xy_list_list = []
for img in tqdm(img_list):
    res = yolo_model(img)
    res_refine = res.pandas().xyxy[0].values

    nms_human = len(res_refine)
    if nms_human > 0:
        for bbox in res_refine:
            xx1, yy1, xx2, yy2 = int(bbox[0])-10, int(bbox[1]), int(bbox[2])+10, int(bbox[3])
            if xx1 < 0:
                xx1 = 0
            elif xx2 > 639:
                xx2 = 639
            if yy1 < 0:
                yy1 = 0
            elif yy2 > 639:
                yy2 = 639

            start_point = (xx1, yy1)
            end_point = (xx2, yy2)
            if bbox[4] > y_CONFIDENCE:
                img = cv2.rectangle(img, start_point, end_point, (0, 0, 255), 2)

                c_img = img[yy1:yy2, xx1:xx2]
                results = pose.process(cv2.cvtColor(c_img, cv2.COLOR_BGR2RGB)) # Yolo 바운딩 box 안에서 landmark dot 추출
                if not results.pose_landmarks: continue
                xy_list = []
                idx = 0
                draw_line_dic = {}
                for x_and_y in results.pose_landmarks.landmark:
                    if idx in attention_dot:
                        xy_list.append(x_and_y.x)
                        xy_list.append(x_and_y.y)
                        x, y = int(x_and_y.x*(xx2-xx1)), int(x_and_y.y*(yy2-yy1))
                        draw_line_dic[idx] = [x, y]
                    idx += 1

                xy_list_list.append(xy_list)
                for line in draw_line:
                    x1, y1 = draw_line_dic[line[0]][0], draw_line_dic[line[0]][1]
                    x2, y2 = draw_line_dic[line[1]][0], draw_line_dic[line[1]][1]
                    c_img = cv2.line(c_img, (x1, y1), (x2, y2), (0, 255, 0), 3)

                if len(xy_list_list) == length:
                    dataset = []
                    dataset.append({'key' : 0, 'value' : xy_list_list})
                    dataset = MyDataset(dataset)
                    dataset = DataLoader(dataset)
                    xy_list_list = []

                    for data, label in dataset:
                        data = data.to(device)
                        with torch.no_grad():
                            result = net(data)
                            _, out = torch.max(result, 1)
                            if out.item() == 0: status = 'Normal'
                            else: status = 'Theft'

    cv2.putText(img, status, (0, 50), cv2.FONT_HERSHEY_COMPLEX, 1.5, (0, 0, 255), 2)
    out_img_list.append(img)
# Out:
# I0000 00:00:1723527563.321768 1328244 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1723527563.338189 1331585 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 535.183.01), renderer: NVIDIA GeForce RTX 3090/PCIe/SSE2
# 시퀀스 데이터 분석 중...
#   0%|          | 0/180 [00:00<?, ?it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   1%|          | 1/180 [00:00<00:54,  3.29it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   1%|          | 2/180 [00:00<00:47,  3.76it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   2%|▏         | 3/180 [00:00<00:49,  3.56it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   2%|▏         | 4/180 [00:01<00:48,  3.61it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   3%|▎         | 5/180 [00:01<00:48,  3.61it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   3%|▎         | 6/180 [00:01<00:49,  3.51it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   4%|▍         | 7/180 [00:01<00:46,  3.73it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   4%|▍         | 8/180 [00:02<00:45,  3.78it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   5%|▌         | 9/180 [00:02<00:45,  3.80it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   6%|▌         | 10/180 [00:02<00:47,  3.59it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   6%|▌         | 11/180 [00:02<00:44,  3.77it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   7%|▋         | 12/180 [00:03<00:44,  3.79it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   7%|▋         | 13/180 [00:03<00:43,  3.83it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   8%|▊         | 14/180 [00:03<00:41,  3.96it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   8%|▊         | 15/180 [00:03<00:40,  4.09it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   9%|▉         | 16/180 [00:04<00:40,  4.08it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#   9%|▉         | 17/180 [00:04<00:40,  4.01it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  10%|█         | 18/180 [00:04<00:40,  3.99it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  11%|█         | 19/180 [00:04<00:40,  3.97it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  11%|█         | 20/180 [00:05<00:42,  3.73it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  12%|█▏        | 21/180 [00:05<00:42,  3.75it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  12%|█▏        | 22/180 [00:05<00:42,  3.72it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  13%|█▎        | 23/180 [00:06<00:43,  3.63it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  13%|█▎        | 24/180 [00:06<00:43,  3.55it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  14%|█▍        | 25/180 [00:06<00:42,  3.61it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  14%|█▍        | 26/180 [00:06<00:44,  3.49it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  15%|█▌        | 27/180 [00:07<00:45,  3.34it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  16%|█▌        | 28/180 [00:07<00:44,  3.42it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  16%|█▌        | 29/180 [00:07<00:45,  3.35it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  17%|█▋        | 30/180 [00:08<00:45,  3.32it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  17%|█▋        | 31/180 [00:08<00:44,  3.35it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  18%|█▊        | 32/180 [00:08<00:44,  3.35it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  18%|█▊        | 33/180 [00:09<00:43,  3.36it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  19%|█▉        | 34/180 [00:09<00:42,  3.44it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  19%|█▉        | 35/180 [00:09<00:41,  3.47it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  20%|██        | 36/180 [00:09<00:41,  3.46it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  21%|██        | 37/180 [00:10<00:42,  3.37it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  21%|██        | 38/180 [00:10<00:42,  3.36it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  22%|██▏       | 39/180 [00:10<00:40,  3.48it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  22%|██▏       | 40/180 [00:11<00:38,  3.67it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  23%|██▎       | 41/180 [00:11<00:38,  3.60it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  23%|██▎       | 42/180 [00:11<00:39,  3.48it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  24%|██▍       | 43/180 [00:11<00:39,  3.44it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  24%|██▍       | 44/180 [00:12<00:41,  3.26it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  25%|██▌       | 45/180 [00:12<00:42,  3.15it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  26%|██▌       | 46/180 [00:12<00:43,  3.05it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  26%|██▌       | 47/180 [00:13<00:40,  3.30it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  27%|██▋       | 48/180 [00:13<00:40,  3.25it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  27%|██▋       | 49/180 [00:13<00:38,  3.41it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  28%|██▊       | 50/180 [00:14<00:38,  3.34it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  28%|██▊       | 51/180 [00:14<00:38,  3.34it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  29%|██▉       | 52/180 [00:14<00:37,  3.42it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  29%|██▉       | 53/180 [00:15<00:37,  3.38it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  30%|███       | 54/180 [00:15<00:38,  3.23it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  31%|███       | 55/180 [00:15<00:38,  3.21it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  31%|███       | 56/180 [00:15<00:38,  3.23it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  32%|███▏      | 57/180 [00:16<00:38,  3.23it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  32%|███▏      | 58/180 [00:16<00:37,  3.27it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  33%|███▎      | 59/180 [00:16<00:37,  3.26it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  33%|███▎      | 60/180 [00:17<00:37,  3.22it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  34%|███▍      | 61/180 [00:17<00:36,  3.27it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  34%|███▍      | 62/180 [00:17<00:34,  3.39it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  35%|███▌      | 63/180 [00:18<00:34,  3.44it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  36%|███▌      | 64/180 [00:18<00:33,  3.46it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  36%|███▌      | 65/180 [00:18<00:32,  3.53it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  37%|███▋      | 66/180 [00:18<00:32,  3.51it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  37%|███▋      | 67/180 [00:19<00:32,  3.43it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  38%|███▊      | 68/180 [00:19<00:33,  3.37it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  38%|███▊      | 69/180 [00:19<00:32,  3.37it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  39%|███▉      | 70/180 [00:20<00:31,  3.50it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  39%|███▉      | 71/180 [00:20<00:32,  3.33it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  40%|████      | 72/180 [00:20<00:31,  3.45it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  41%|████      | 73/180 [00:20<00:31,  3.44it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  41%|████      | 74/180 [00:21<00:31,  3.41it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  42%|████▏     | 75/180 [00:21<00:30,  3.40it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  42%|████▏     | 76/180 [00:21<00:29,  3.47it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  43%|████▎     | 77/180 [00:22<00:30,  3.39it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  43%|████▎     | 78/180 [00:22<00:30,  3.34it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  44%|████▍     | 79/180 [00:22<00:29,  3.41it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  44%|████▍     | 80/180 [00:23<00:30,  3.32it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  45%|████▌     | 81/180 [00:23<00:29,  3.31it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  46%|████▌     | 82/180 [00:23<00:30,  3.23it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  46%|████▌     | 83/180 [00:24<00:30,  3.18it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  47%|████▋     | 84/180 [00:24<00:29,  3.27it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  47%|████▋     | 85/180 [00:24<00:27,  3.44it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  48%|████▊     | 86/180 [00:24<00:26,  3.57it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  48%|████▊     | 87/180 [00:25<00:26,  3.48it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  49%|████▉     | 88/180 [00:25<00:26,  3.50it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  49%|████▉     | 89/180 [00:25<00:25,  3.59it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  50%|█████     | 90/180 [00:25<00:26,  3.45it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  51%|█████     | 91/180 [00:26<00:25,  3.55it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  51%|█████     | 92/180 [00:26<00:24,  3.60it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  52%|█████▏    | 93/180 [00:26<00:24,  3.58it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  52%|█████▏    | 94/180 [00:27<00:23,  3.62it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  53%|█████▎    | 95/180 [00:27<00:23,  3.70it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  53%|█████▎    | 96/180 [00:27<00:23,  3.64it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  54%|█████▍    | 97/180 [00:27<00:21,  3.80it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  54%|█████▍    | 98/180 [00:28<00:20,  3.93it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  55%|█████▌    | 99/180 [00:28<00:21,  3.85it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  56%|█████▌    | 100/180 [00:28<00:21,  3.64it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  56%|█████▌    | 101/180 [00:28<00:21,  3.62it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  57%|█████▋    | 102/180 [00:29<00:21,  3.58it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  57%|█████▋    | 103/180 [00:29<00:22,  3.44it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  58%|█████▊    | 104/180 [00:29<00:22,  3.41it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  58%|█████▊    | 105/180 [00:30<00:23,  3.22it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  59%|█████▉    | 106/180 [00:30<00:23,  3.20it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  59%|█████▉    | 107/180 [00:30<00:24,  2.98it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  60%|██████    | 108/180 [00:31<00:23,  3.09it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  61%|██████    | 109/180 [00:31<00:22,  3.13it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  61%|██████    | 110/180 [00:31<00:22,  3.10it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  62%|██████▏   | 111/180 [00:32<00:21,  3.24it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  62%|██████▏   | 112/180 [00:32<00:20,  3.33it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  63%|██████▎   | 113/180 [00:32<00:19,  3.48it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  63%|██████▎   | 114/180 [00:32<00:19,  3.45it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  64%|██████▍   | 115/180 [00:33<00:17,  3.62it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  64%|██████▍   | 116/180 [00:33<00:18,  3.55it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  65%|██████▌   | 117/180 [00:33<00:18,  3.43it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  66%|██████▌   | 118/180 [00:34<00:19,  3.21it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  66%|██████▌   | 119/180 [00:34<00:18,  3.28it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  67%|██████▋   | 120/180 [00:34<00:18,  3.31it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  67%|██████▋   | 121/180 [00:35<00:18,  3.25it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  68%|██████▊   | 122/180 [00:35<00:17,  3.35it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  68%|██████▊   | 123/180 [00:35<00:16,  3.43it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  69%|██████▉   | 124/180 [00:35<00:15,  3.56it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  69%|██████▉   | 125/180 [00:36<00:15,  3.56it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  70%|███████   | 126/180 [00:36<00:15,  3.59it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  71%|███████   | 127/180 [00:36<00:14,  3.54it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  71%|███████   | 128/180 [00:37<00:15,  3.42it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  72%|███████▏  | 129/180 [00:37<00:14,  3.40it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  72%|███████▏  | 130/180 [00:37<00:14,  3.48it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  73%|███████▎  | 131/180 [00:37<00:14,  3.43it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  73%|███████▎  | 132/180 [00:38<00:13,  3.46it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  74%|███████▍  | 133/180 [00:38<00:13,  3.48it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  74%|███████▍  | 134/180 [00:38<00:13,  3.43it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  75%|███████▌  | 135/180 [00:39<00:13,  3.41it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  76%|███████▌  | 136/180 [00:39<00:13,  3.27it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  76%|███████▌  | 137/180 [00:39<00:13,  3.16it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  77%|███████▋  | 138/180 [00:40<00:13,  3.08it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  77%|███████▋  | 139/180 [00:40<00:12,  3.18it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  78%|███████▊  | 140/180 [00:40<00:13,  3.02it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  78%|███████▊  | 141/180 [00:41<00:13,  3.00it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  79%|███████▉  | 142/180 [00:41<00:12,  3.10it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  79%|███████▉  | 143/180 [00:41<00:11,  3.18it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  80%|████████  | 144/180 [00:41<00:11,  3.14it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  81%|████████  | 145/180 [00:42<00:10,  3.26it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  81%|████████  | 146/180 [00:42<00:10,  3.32it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  82%|████████▏ | 147/180 [00:42<00:10,  3.26it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  82%|████████▏ | 148/180 [00:43<00:09,  3.31it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  83%|████████▎ | 149/180 [00:43<00:09,  3.28it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  83%|████████▎ | 150/180 [00:43<00:09,  3.30it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  84%|████████▍ | 151/180 [00:44<00:08,  3.33it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  84%|████████▍ | 152/180 [00:44<00:08,  3.26it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  85%|████████▌ | 153/180 [00:44<00:08,  3.24it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  86%|████████▌ | 154/180 [00:44<00:07,  3.42it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  86%|████████▌ | 155/180 [00:45<00:07,  3.54it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  87%|████████▋ | 156/180 [00:45<00:07,  3.33it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  87%|████████▋ | 157/180 [00:45<00:06,  3.43it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  88%|████████▊ | 158/180 [00:46<00:06,  3.35it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  88%|████████▊ | 159/180 [00:46<00:06,  3.21it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  89%|████████▉ | 160/180 [00:46<00:06,  3.29it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  89%|████████▉ | 161/180 [00:47<00:05,  3.28it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  90%|█████████ | 162/180 [00:47<00:05,  3.17it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  91%|█████████ | 163/180 [00:47<00:05,  3.19it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  91%|█████████ | 164/180 [00:48<00:04,  3.23it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  92%|█████████▏| 165/180 [00:48<00:04,  3.24it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  92%|█████████▏| 166/180 [00:48<00:04,  3.22it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  93%|█████████▎| 167/180 [00:48<00:03,  3.40it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  93%|█████████▎| 168/180 [00:49<00:03,  3.55it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  94%|█████████▍| 169/180 [00:49<00:03,  3.52it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  94%|█████████▍| 170/180 [00:49<00:02,  3.52it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  95%|█████████▌| 171/180 [00:50<00:02,  3.38it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  96%|█████████▌| 172/180 [00:50<00:02,  3.37it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  96%|█████████▌| 173/180 [00:50<00:02,  3.32it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  97%|█████████▋| 174/180 [00:50<00:01,  3.29it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  97%|█████████▋| 175/180 [00:51<00:01,  3.30it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  98%|█████████▊| 176/180 [00:51<00:01,  3.38it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  98%|█████████▊| 177/180 [00:51<00:00,  3.46it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  99%|█████████▉| 178/180 [00:52<00:00,  3.51it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
#  99%|█████████▉| 179/180 [00:52<00:00,  3.27it/s]/home/nkw/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# 100%|██████████| 180/180 [00:52<00:00,  3.41it/s]

# %%
# 테스트 원본 영상 내보내기
filename = './output.mp4'
fourcc = cv2.VideoWriter_fourcc(*'DIVX')
fps = 3
frameSize = (640, 640)
isColor = True
out = cv2.VideoWriter(filename, fourcc, fps, frameSize, isColor)
for out_img in out_img_list:
    out.write(out_img)
out.release()
# Out:
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'

# %% [markdown]
# - 모델 저장

# %%
# 모델 저장하기
PATH = '/content/drive/MyDrive/'
PATH = '/home/nkw/ihs/ihs2/zerobase_DL_project/'
model_name = 'LSTM.pt'
torch.save(net.state_dict(), PATH + model_name)
